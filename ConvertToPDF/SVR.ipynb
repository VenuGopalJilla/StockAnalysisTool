# %%
import csv
import numpy as np
import pandas as pd
import glob, os
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from datetime import *
from sklearn.svm import SVR
from sklearn import svm
from sklearn.metrics import mean_absolute_error,mean_squared_error
import seaborn as sns
from sklearn.model_selection import GridSearchCV
import warnings; warnings.simplefilter('ignore')
from sklearn.metrics import r2_score
from sklearn.metrics import median_absolute_error
from sklearn.metrics import explained_variance_score

from prettytable import PrettyTable

from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import f_regression
import statsmodels.api as sm

# %%
path = os.getcwd()
path
# Out:
# 'C:\\Users\\venu\\Desktop\\Stock Market Analysis'

# %% [markdown]
# # Pre-processing the Data

# %%
def pre_process_data(data,null_threshold):
    data.drop(columns=['Unix Date','Date'],axis=1,inplace=True)
    total = data.shape[0]
    for col in data.columns:
        if ((null_threshold * total / 100) < data[col].isnull().sum()):
            data.drop(columns=[col],axis=1,inplace=True)
    data.replace([np.inf, -np.inf], np.nan, inplace=True)
    data.dropna(axis=0,inplace=True)
    return data

# %% [markdown]
# # Removing columns based on the dependent column

# %%
def dependent_column(data,column):
    cols = [col for col in data.columns if ("next" not in col.lower() and col.lower().endswith("gr"))]
    cols.append(column)
    data = data[cols]
    return (data,column)

# %%
def forward_selection(data, target, significance_level=0.05):
    initial_features = data.columns.tolist()
    best_features = []
    while (len(initial_features)>0):
        remaining_features = list(set(initial_features)-set(best_features))
        new_pval = pd.Series(index=remaining_features)
        for new_column in remaining_features:
            model = sm.OLS(target, sm.add_constant(data[best_features+[new_column]]).astype(float)).fit()
            new_pval[new_column] = model.pvalues[new_column]
        min_p_value = new_pval.min()
        if(min_p_value<significance_level):
            best_features.append(new_pval.idxmin())
        else:
            break
    return best_features

# %%
def backward_elimination(data, target,significance_level = 0.05):
    features = data.columns.tolist()
    while(len(features)>0):
        features_with_constant = sm.add_constant(data[features]).astype(float)
        p_values = sm.OLS(target, features_with_constant).fit().pvalues[1:]
        max_p_value = p_values.max()
        if(max_p_value >= significance_level):
            excluded_feature = p_values.idxmax()
            features.remove(excluded_feature)
        else:
            break 
    return features

# %% [markdown]
# # ---

# %%
def Model(dataset,y):
    X = dataset.loc[:, dataset.columns != y]
    Y = dataset.loc[:, dataset.columns == y]
    count = 3
    step = 1000
    start = 1
    end = 10000
    while(count >= 0):
#         print("start  ------> " + str(start))
#         print("end    ------> " + str(end))
#         print("step   ------> " + str(step))
        best,step = bestParameters(start,end,step,X,Y)
        for key in best:
            if key == 'C':
                c = best[key]
                print(c)
        if(count == 3):
            start = c - 1000
            end = c + 1000
        if(count == 2):
            start = c - 100
            end = c + 100
        if(count == 1):
            start = c - 10
            end = c + 10
        step = step/10
        count = count - 1 
#         print("count : " , count)
    return c

# %%
def bestParameters(start,end,step,X,Y):
    parameters = {'kernel': ['rbf'], 'C': np.arange(start,end,step),  
              'gamma': [0.0001],'epsilon':[0.01]}
#     print("parameters ", parameters)
    svr = svm.SVR(gamma = 'auto')
    clf = GridSearchCV(svr, parameters, scoring = 'neg_mean_squared_error')
    X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=42)
    clf.fit(X_train,y_train)
    best = clf.best_params_
#     print("best ", best)
    return (best,step)

# %% [markdown]
# # Finding results from each set of important features

# %%
columns = ['Company','Method','Percentage', 'r^2_score', 'Mean_SE', 'Mean_AE', 'Median_AE','EVS']

# %%
companies = {"500112" : "SBIN" ,
"500325" : "RELIANCE INDUSTRIES LTD",
"532540" : "TATA CONSULTANCY SERVICES LTD" ,
"500209" : "INFOSYS LTD", 
"532174" : "ICICI BANK LTD", 
"507685" : "WIPRO LTD", 
"530965" : "INDIAN OIL CORPORATION LTD", 
"500182" : "HERO MOTOCORP LTD", 
"532210" : "CITY UNION BANK LTD", 
"500180" : "HDFC Bank Ltd",
"500680" : "PFIZER LTD"}

# %%
models = ["SVR"]
tables = {model:PrettyTable() for model in models}
for name,table in tables.items():
    table.field_names = columns

# %%
final_df = pd.read_csv("C:\\Users\\venu\\Desktop\\Stock Market Analysis\\Final_Results_df.csv")
final_df.drop('Unnamed: 0', inplace = True, axis = 'columns')
final_df
# Out:
#                                  Company                   Model  \
# 0                            500112-SBIN       Linear Regression
# 1                            500112-SBIN        Ridge Regression
# 2                            500112-SBIN        Lasso Regression
# 3                            500112-SBIN  Elastic Net Regression
# 4                   500180-HDFC Bank Ltd       Linear Regression
# 5                   500180-HDFC Bank Ltd        Ridge Regression
# 6                   500180-HDFC Bank Ltd        Lasso Regression
# 7                   500180-HDFC Bank Ltd  Elastic Net Regression
# 8               500182-HERO MOTOCORP LTD       Linear Regression
# 9               500182-HERO MOTOCORP LTD        Ridge Regression
# 10              500182-HERO MOTOCORP LTD        Lasso Regression
# 11              500182-HERO MOTOCORP LTD  Elastic Net Regression
# 12                    500209-INFOSYS LTD       Linear Regression
# 13                    500209-INFOSYS LTD        Ridge Regression
# 14                    500209-INFOSYS LTD        Lasso Regression
# 15                    500209-INFOSYS LTD  Elastic Net Regression
# 16        500325-RELIANCE INDUSTRIES LTD       Linear Regression
# 17        500325-RELIANCE INDUSTRIES LTD        Ridge Regression
# 18        500325-RELIANCE INDUSTRIES LTD        Lasso Regression
# 19        500325-RELIANCE INDUSTRIES LTD  Elastic Net Regression
# 20                     500680-PFIZER LTD       Linear Regression
# 21                     500680-PFIZER LTD        Ridge Regression
# 22                     500680-PFIZER LTD        Lasso Regression
# 23                     500680-PFIZER LTD  Elastic Net Regression
# 24                      507685-WIPRO LTD       Linear Regression
# 25                      507685-WIPRO LTD        Ridge Regression
# 26                      507685-WIPRO LTD        Lasso Regression
# 27                      507685-WIPRO LTD  Elastic Net Regression
# 28     530965-INDIAN OIL CORPORATION LTD       Linear Regression
# 29     530965-INDIAN OIL CORPORATION LTD        Ridge Regression
# 30     530965-INDIAN OIL CORPORATION LTD        Lasso Regression
# 31     530965-INDIAN OIL CORPORATION LTD  Elastic Net Regression
# 32                 532174-ICICI BANK LTD       Linear Regression
# 33                 532174-ICICI BANK LTD        Ridge Regression
# 34                 532174-ICICI BANK LTD        Lasso Regression
# 35                 532174-ICICI BANK LTD  Elastic Net Regression
# 36            532210-CITY UNION BANK LTD       Linear Regression
# 37            532210-CITY UNION BANK LTD        Ridge Regression
# 38            532210-CITY UNION BANK LTD        Lasso Regression
# 39            532210-CITY UNION BANK LTD  Elastic Net Regression
# 40  532540-TATA CONSULTANCY SERVICES LTD       Linear Regression
# 41  532540-TATA CONSULTANCY SERVICES LTD        Ridge Regression
# 42  532540-TATA CONSULTANCY SERVICES LTD        Lasso Regression
# 43  532540-TATA CONSULTANCY SERVICES LTD  Elastic Net Regression
#
#                           Method  Percentage
# 0             LinearFIPValue0.05    0.528953
# 1                RidgeFIFValue10    0.504454
# 2               LassoFIFValue100    0.511136
# 3             ElasticFIFValue100    0.503341
# 4                LinearFIFValue1    0.488294
# 5                 RidgeFIFValue1    0.486065
# 6                 LassoFIFValue1    0.488294
# 7               ElasticFIFValue1    0.488294
# 8    LinearFIBackwardElimination    0.537778
# 9     RidgeFIBackwardElimination    0.537778
# 10    LassoFIBackwardElimination    0.537778
# 11  ElasticFIBackwardElimination    0.537778
# 12       LinearFICoefficients0.1    0.506118
# 13       RidgeFIForwardSelection    0.494994
# 14                LassoFIFValue1    0.490545
# 15      ElasticFICoefficients0.1    0.511680
# 16            LinearFIPValue0.05    0.502781
# 17    RidgeFIBackwardElimination    0.500556
# 18              LassoFIFValue100    0.479422
# 19            ElasticFIFValue100    0.479422
# 20      LinearFIForwardSelection    0.539773
# 21       RidgeFIForwardSelection    0.538636
# 22       LassoFIForwardSelection    0.539773
# 23     ElasticFIForwardSelection    0.539773
# 24       LinearFICoefficients0.1    0.516741
# 25              RidgeFIFValue100    0.511161
# 26              LassoFIPValue0.2    0.517857
# 27            ElasticFIFValue100    0.513393
# 28             LinearFIFValue100    0.516201
# 29               RidgeFIFValue10    0.525140
# 30              LassoFIPValue0.2    0.517318
# 31            ElasticFIPValue0.2    0.517318
# 32   LinearFIBackwardElimination    0.501114
# 33    RidgeFIBackwardElimination    0.510022
# 34             LassoFIFValue1000    0.514477
# 35           ElasticFIFValue1000    0.507795
# 36   LinearFIBackwardElimination    0.489631
# 37                RidgeFIFValue1    0.508065
# 38                LassoFIFValue1    0.482719
# 39              ElasticFIFValue1    0.482719
# 40             LinearFIPValue0.2    0.493990
# 41             RidgeFIPValue0.05    0.480769
# 42              LassoFIFValue100    0.491587
# 43            ElasticFIFValue100    0.489183

# %%
final_df.columns
# Out:
# Index(['Company', 'Model', 'Method', 'Percentage'], dtype='object')

# %%
def create_pretty_table(name, model, result, method, percentage):
    values = [name[2 : 8 ] + "-" + companies[name[2 : 8]], method, round(percentage, 6)] + [round(v, 6) for k,v in result.items() if not isinstance(v,dict)]
    tables[model].add_row(values)
    tables[model].title = model

# %%
def fit_SVR(df, column, method, value, name, results):
    print("SVR Model fitted using columns obtained from feature importance using " + method + " : ")
    c = Model(df, column)
#     print(c)
    X = df.loc[:, df.columns != column]
    Y = df.loc[:, df.columns == column]
    X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=42)
    svr_rbf = SVR(kernel='rbf', C = 144, gamma = 0.0001, epsilon = 0.01)
    y_rbf = svr_rbf.fit(X_train, y_train).predict(X_test)
    
    y_rbf = y_rbf.astype(float)
    y_test = y_test[column]

    pred_actual = pd.DataFrame(list(zip(y_rbf, y_test)), 
                   columns =['Predicted Values', 'Actual Values'])
    pred_actual.to_csv("C:\\Users\\venu\\Desktop\\Stock Market Analysis\\Data\Models Results\\" + "SVR_" + "FI_" + method + "_" + str(value) + "_" + name + ".csv" , index=False)
    
    same_dir = 0
    diff_dir = 0
    for a, b in zip(y_rbf, y_test) :
        if (a > 0 and b > 0) or (a < 0 and b < 0):
            same_dir += 1
        else:
            diff_dir += 1
    percentage = (same_dir / (same_dir + diff_dir))
    print("Values in Same direction -----> ----->", same_dir)
    print("Values in Opposite direction <----- -----> ", diff_dir)
    print("Percentage of correct direction : ", percentage)
    results["SVR_FI_" + method + "_" + str(value)] = percentage
    
    r = r2_score(y_test, y_rbf)
    mse = mean_squared_error(y_test, y_rbf)
    mae = mean_absolute_error(y_test, y_rbf)
    med = median_absolute_error(y_test, y_rbf)
    var = explained_variance_score(y_test, y_rbf)
    
    model_result = {'r' : r, "mse" : mse, "mae" : mae, 'med_ae' : med, 'evs' : var}
    
    create_pretty_table(name , "SVR", model_result, method + " " + value, percentage)

# %%
def get_results_from_FI_Coeffiecients(df, name, column, results):
    print("Features Importance using Coefficients")
    print("*****************************************************************************************")
    X = df[df.columns[:-1]]
    Y = df[column].values
    model_linear = LinearRegression(fit_intercept=True)
    model_linear.fit(X, Y)
    col_coef = list(df.columns)
    res_coef = [round(i,6) for i in list(model_linear.coef_)]
    rc_coef = list(zip(col_coef, res_coef))
    coef_features = []
    coef = [0.1]
    method = "Coefficients"
    for cf in coef:
        for i in range(len(rc_coef)):
            if ((abs(rc_coef[i][1])) > cf):
                coef_features.append(rc_coef[i][0])
        print("Features obtained from coefficients greater than " + str(cf) + " : ")
        print("--------------------------------------")
        print(coef_features)
        if (len(coef_features) == 0):
            continue
        coef_features.append(column)
        df_fic = df[coef_features]
        fit_SVR(df_fic, column, method, str(cf), name, results)
    print("*****************************************************************************************")

# %%
def get_results_from_FI_PValue(df, name, column, results):
    print("Features Importance using p-value")
    print("*****************************************************************************************")
    X = df[df.columns[:-1]]
    Y = df[column].values
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=0)
    X_train = np.array(X_train, dtype=float)
    ols_model = sm.OLS(Y_train, X_train).fit()
    col_pval = list(df.columns)
    pvals = list(ols_model.pvalues)
    pvals_cols = list(zip(col_pval, pvals))
    p = [0.02, 0.05, 0.1, 0.2]
    method = "PValue"
    for pv in p:
        pval_features = []
        for i in range(len(pvals_cols)):
            if (pvals_cols[i][1] < pv):
                pval_features.append(pvals_cols[i][0])
        print("Features obtained from p-values less than " + str(pv) + " : ")
        print("-------------------------------------------------")
        print(pval_features)
        if (len(pval_features) == 0):
            continue
        pval_features.append(column)
        df_fip = df[pval_features]
        fit_SVR(df_fip, column, method, str(pv), name, results)
    print("*****************************************************************************************")

# %%
def get_results_from_FI_FValues(df, name, column, results):
    print("Features Importance using f-value")
    print("*****************************************************************************************")
    X = df[df.columns[:-1]]
    Y = df[column].values
    fval_cols = X.columns
    freg_res = f_regression(X, Y)
#     print(freg_res[0])
    fvals = freg_res[0]
    fc = list(zip(fval_cols, fvals))
    f = [1, 10, 100, 1000]
    method = "FValue"
    for fv in f :
        fval_features = []
        for i in range(len(fc)):
            if ((abs(fc[i][1])) > fv):
                fval_features.append(fc[i][0])
        print("Features obtained from f-values greater than " + str(fv) + " : ")
        print("--------------------------------------")
        print(fval_features)
        if (len(fval_features) == 0):
            continue
        fval_features.append(column)
        df_fif = df[fval_features]
        fit_SVR(df_fif, column, method, str(fv), name, results)
    print("*****************************************************************************************")

# %%
def get_results_from_FI_ForwardSelection(df1, name, column, results):
    print("Features Importance using Forward Selection Method")
    print("*****************************************************************************************")
    method = "ForwardSelection"
    X = df1[df1.columns[:-1]]
    Y = df1[column].values
    forward_features = forward_selection(X,Y)
    print("Features obtained from Forward Selection method : ") 
    print("--------------------------------------")
    print(forward_features)
    if (len(forward_features) == 0):
        pass
    forward_features.append(column)
    df_fs = df1[forward_features]
    fit_SVR(df_fs, column, method, '', name, results)
    print("*****************************************************************************************")

# %%
def get_results_from_FI_BackwardElimination(df1, name, column, results):
    print("Features Importance using Backward Elimination Method")
    print("*****************************************************************************************")
    method = "BackwardElimination"
    X = df1[df1.columns[:-1]]
    Y = df1[column].values
    backward_features = backward_elimination(X,Y)
    print("Features obtained from Backward Elimination method : ") 
    print("--------------------------------------")
    print(backward_features)
    if (len(backward_features) == 0):
        pass
    backward_features.append(column)
    df_be = df1[backward_features]
    fit_SVR(df_be, column, method, '', name, results)
    print("*****************************************************************************************")

# %%
def get_results_from_each_set(data, name, final_df):
    df = pre_process_data(data, 60)
    column = "Next Day Close Price GR"
    (df1, column) = dependent_column(df, column)
    results = {}
    get_results_from_FI_Coeffiecients(df1, name, column, results)
    get_results_from_FI_PValue(df1, name, column, results)
    get_results_from_FI_ForwardSelection(df1, name, column, results)
    get_results_from_FI_BackwardElimination(df1, name, column, results)
    get_results_from_FI_FValues(df1, name, column, results)

    sorted_results = sorted(results.items(), key=lambda item: item[1])
    max_row = {'Company' : name[2 : 8] + "-" + companies[name[2 : 8]], 'Model' : 'SVR', 'Method' : sorted_results[-1][0], 'Percentage' : sorted_results[-1][1]}
    final_df = final_df.append(max_row, ignore_index = True)
    print("Maximum correct direction values are obtained for {} with a percentage of {}.".format(sorted_results[-1][0], sorted_results[-1][1]))
    return final_df

# %%
# %%time
for filename in os.listdir(os.path.join(path,"Data/Stock")):
    if filename.startswith("gr"):
        df_svr = pd.read_csv(os.path.join(path,"Data\Stock\\" + filename))
        name = os.path.join(path, "Data\Stock\\" + filename).split("\\")[-1]
        stock = name[2 : 8]
        fd_df = pd.DataFrame(columns = final_df.columns)
        print("For stock : ", stock)
        print("#################################################################################################################")
        f_df = get_results_from_each_set(df_svr, name, fd_df)
        final_df = final_df.append(f_df, ignore_index = True)
        print("#################################################################################################################")

final_df.to_csv('C:\\Users\\venu\\Desktop\\Stock Market Analysis\\Final_Results_df.csv')
# Out:
# For stock :  500112
# #################################################################################################################
# Features Importance using Coefficients
# *****************************************************************************************
# Features obtained from coefficients greater than 0.1 :
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR', 'No.of Shares GR', 'Total Turnover (Rs.) GR', 'Alpha GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using Coefficients :
# 1
# 1.0
# 1.0
# 1.0
# Values in Same direction -----> -----> 435
# Values in Opposite direction <----- ----->  463
# Percentage of correct direction :  0.4844097995545657
# *****************************************************************************************
# Features Importance using p-value
# *****************************************************************************************
# Features obtained from p-values less than 0.02 :
# -------------------------------------------------
# ['Alpha GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 6001
# 5901.0
# 5931.0
# 5937.0
# Values in Same direction -----> -----> 435
# Values in Opposite direction <----- ----->  463
# Percentage of correct direction :  0.4844097995545657
# Features obtained from p-values less than 0.05 :
# -------------------------------------------------
# ['Open Price GR', 'No. of Trades GR', 'Alpha GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 1
# 101.0
# 61.0
# 64.0
# Values in Same direction -----> -----> 451
# Values in Opposite direction <----- ----->  447
# Percentage of correct direction :  0.5022271714922049
# Features obtained from p-values less than 0.1 :
# -------------------------------------------------
# ['Open Price GR', 'No.of Shares GR', 'No. of Trades GR', 'Deliverable Quantity GR', '% Deli. Qty to Traded Qty GR', 'Alpha GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 1
# 1.0
# 61.0
# 64.0
# Values in Same direction -----> -----> 442
# Values in Opposite direction <----- ----->  456
# Percentage of correct direction :  0.4922048997772829
# Features obtained from p-values less than 0.2 :
# -------------------------------------------------
# ['Open Price GR', 'High Price GR', 'Close Price GR', 'No.of Shares GR', 'No. of Trades GR', 'Total Turnover (Rs.) GR', 'Deliverable Quantity GR', '% Deli. Qty to Traded Qty GR', 'Alpha GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 1
# 1.0
# 61.0
# 53.0
# Values in Same direction -----> -----> 444
# Values in Opposite direction <----- ----->  454
# Percentage of correct direction :  0.49443207126948774
# *****************************************************************************************
# Features Importance using Forward Selection Method
# *****************************************************************************************
# Features obtained from Forward Selection method :
# --------------------------------------
# ['Beta GR', 'Close Price GR', 'Spread High-Low GR', 'Low Price GR', 'High Price GR', 'Alpha GR', 'No.of Shares GR', 'Total Turnover (Rs.) GR', 'No. of Trades GR', 'WAP GR', 'Open Price GR']
# SVR Model fitted using columns obtained from feature importance using ForwardSelection :
# 1
# 1.0
# 1.0
# 1.0
# Values in Same direction -----> -----> 451
# Values in Opposite direction <----- ----->  447
# Percentage of correct direction :  0.5022271714922049
# *****************************************************************************************
# Features Importance using Backward Elimination Method
# *****************************************************************************************
# Features obtained from Backward Elimination method :
# --------------------------------------
# ['Open Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR', 'No.of Shares GR', 'No. of Trades GR', 'Total Turnover (Rs.) GR', 'Spread High-Low GR', 'Alpha GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using BackwardElimination :
# 1
# 1.0
# 1.0
# 1.0
# Values in Same direction -----> -----> 450
# Values in Opposite direction <----- ----->  448
# Percentage of correct direction :  0.5011135857461024
# *****************************************************************************************
# Features Importance using f-value
# *****************************************************************************************
# Features obtained from f-values greater than 1 :
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR', 'Spread High-Low GR', 'Alpha GR', 'Beta GR', 'Revenue GR', 'Dividend Value GR', 'Income GR']
# SVR Model fitted using columns obtained from feature importance using FValue :
# 1
# 1.0
# 41.0
# 43.0
# Values in Same direction -----> -----> 439
# Values in Opposite direction <----- ----->  459
# Percentage of correct direction :  0.4888641425389755
# Features obtained from f-values greater than 10 :
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR', 'Spread High-Low GR', 'Alpha GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using FValue :
# 1
# 1.0
# 51.0
# 50.0
# Values in Same direction -----> -----> 439
# Values in Opposite direction <----- ----->  459
# Percentage of correct direction :  0.4888641425389755
# Features obtained from f-values greater than 100 :
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using FValue :
# 1001
# 401.0
# 331.0
# 339.0
# Values in Same direction -----> -----> 453
# Values in Opposite direction <----- ----->  445
# Percentage of correct direction :  0.5044543429844098
# Features obtained from f-values greater than 1000 :
# --------------------------------------
# ['Beta GR']
# SVR Model fitted using columns obtained from feature importance using FValue :
# 7001
# 7101.0
# 7191.0
# 7193.0
# Values in Same direction -----> -----> 434
# Values in Opposite direction <----- ----->  464
# Percentage of correct direction :  0.48329621380846327
# *****************************************************************************************
# Maximum correct direction values are obtained for SVR_FI_FValue_100 with a percentage of 0.5044543429844098.
# #################################################################################################################
# For stock :  500180
# #################################################################################################################
# Features Importance using Coefficients
# *****************************************************************************************
# Features obtained from coefficients greater than 0.1 :
# --------------------------------------
# ['Low Price GR', 'Close Price GR', 'Alpha GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using Coefficients :
# 1
# 1.0
# 1.0
# 1.0
# Values in Same direction -----> -----> 478
# Values in Opposite direction <----- ----->  419
# Percentage of correct direction :  0.5328874024526199
# *****************************************************************************************
# Features Importance using p-value
# *****************************************************************************************
# Features obtained from p-values less than 0.02 :
# -------------------------------------------------
# ['Alpha GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 1
# 1.0
# 1.0
# 2.0
# Values in Same direction -----> -----> 482
# Values in Opposite direction <----- ----->  415
# Percentage of correct direction :  0.5373467112597548
# Features obtained from p-values less than 0.05 :
# -------------------------------------------------
# ['Alpha GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 1
# 1.0
# 1.0
# 2.0
# Values in Same direction -----> -----> 482
# Values in Opposite direction <----- ----->  415
# Percentage of correct direction :  0.5373467112597548
# Features obtained from p-values less than 0.1 :
# -------------------------------------------------
# ['Low Price GR', 'Alpha GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 1
# 1.0
# 1.0
# 2.0
# Values in Same direction -----> -----> 482
# Values in Opposite direction <----- ----->  415
# Percentage of correct direction :  0.5373467112597548
# Features obtained from p-values less than 0.2 :
# -------------------------------------------------
# ['Open Price GR', 'Low Price GR', 'Close Price GR', 'Alpha GR', 'Beta GR', 'Revenue GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 1
# 1.0
# 1.0
# 1.0
# Values in Same direction -----> -----> 429
# Values in Opposite direction <----- ----->  468
# Percentage of correct direction :  0.4782608695652174
# *****************************************************************************************
# Features Importance using Forward Selection Method
# *****************************************************************************************
# Features obtained from Forward Selection method :
# --------------------------------------
# ['Beta GR', 'Alpha GR', 'Spread Close-Open GR', 'Deliverable Quantity GR']
# SVR Model fitted using columns obtained from feature importance using ForwardSelection :
# 1
# 1.0
# 1.0
# 1.0
# Values in Same direction -----> -----> 456
# Values in Opposite direction <----- ----->  441
# Percentage of correct direction :  0.5083612040133779
# *****************************************************************************************
# Features Importance using Backward Elimination Method
# *****************************************************************************************
# Features obtained from Backward Elimination method :
# --------------------------------------
# ['Close Price GR', 'No.of Shares GR', 'No. of Trades GR', 'Total Turnover (Rs.) GR', 'Spread Close-Open GR', 'Alpha GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using BackwardElimination :
# 1
# 1.0
# 1.0
# 1.0
# Values in Same direction -----> -----> 451
# Values in Opposite direction <----- ----->  446
# Percentage of correct direction :  0.5027870680044593
# *****************************************************************************************
# Features Importance using f-value
# *****************************************************************************************
# Features obtained from f-values greater than 1 :
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR', 'No.of Shares GR', 'Spread Close-Open GR', 'Alpha GR', 'Beta GR', 'Dividend Value GR', 'Expenditure GR', 'Net Profit GR']
# SVR Model fitted using columns obtained from feature importance using FValue :
# 1
# 1.0
# 1.0
# 1.0
# Values in Same direction -----> -----> 459
# Values in Opposite direction <----- ----->  438
# Percentage of correct direction :  0.5117056856187291
# Features obtained from f-values greater than 10 :
# --------------------------------------
# ['Alpha GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using FValue :
# 1
# 1.0
# 1.0
# 2.0
# Values in Same direction -----> -----> 482
# Values in Opposite direction <----- ----->  415
# Percentage of correct direction :  0.5373467112597548
# Features obtained from f-values greater than 100 :
# --------------------------------------
# ['Alpha GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using FValue :
# 1
# 1.0
# 1.0
# 2.0
# Values in Same direction -----> -----> 482
# Values in Opposite direction <----- ----->  415
# Percentage of correct direction :  0.5373467112597548
# Features obtained from f-values greater than 1000 :
# --------------------------------------
# ['Beta GR']
# SVR Model fitted using columns obtained from feature importance using FValue :
# 1
# 1.0
# 1.0
# 1.0
# Values in Same direction -----> -----> 485
# Values in Opposite direction <----- ----->  412
# Percentage of correct direction :  0.5406911928651059
# *****************************************************************************************
# Maximum correct direction values are obtained for SVR_FI_FValue_1000 with a percentage of 0.5406911928651059.
# #################################################################################################################
# For stock :  500182
# #################################################################################################################
# Features Importance using Coefficients
# *****************************************************************************************
# Features obtained from coefficients greater than 0.1 :
# --------------------------------------
# ['Net Profit GR', 'EPS GR']
# SVR Model fitted using columns obtained from feature importance using Coefficients :
# 1001
# 1201.0
# 1231.0
# 1233.0
# Values in Same direction -----> -----> 468
# Values in Opposite direction <----- ----->  432
# Percentage of correct direction :  0.52
# *****************************************************************************************
# Features Importance using p-value
# *****************************************************************************************
# Features obtained from p-values less than 0.02 :
# -------------------------------------------------
# ['No. of Trades GR', 'Deliverable Quantity GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 1
# 1.0
# 1.0
# 7.0
# Values in Same direction -----> -----> 434
# Values in Opposite direction <----- ----->  466
# Percentage of correct direction :  0.4822222222222222
# Features obtained from p-values less than 0.05 :
# -------------------------------------------------
# ['No. of Trades GR', 'Deliverable Quantity GR', 'Dividend Value GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 1
# 1.0
# 21.0
# 21.0
# Values in Same direction -----> -----> 450
# Values in Opposite direction <----- ----->  450
# Percentage of correct direction :  0.5
# Features obtained from p-values less than 0.1 :
# -------------------------------------------------
# ['Close Price GR', 'No. of Trades GR', 'Deliverable Quantity GR', 'Dividend Value GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 1
# 1.0
# 1.0
# 10.0
# Values in Same direction -----> -----> 446
# Values in Opposite direction <----- ----->  454
# Percentage of correct direction :  0.4955555555555556
# Features obtained from p-values less than 0.2 :
# -------------------------------------------------
# ['High Price GR', 'Close Price GR', 'No. of Trades GR', 'Deliverable Quantity GR', 'Dividend Value GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 1
# 1.0
# 1.0
# 4.0
# Values in Same direction -----> -----> 455
# Values in Opposite direction <----- ----->  445
# Percentage of correct direction :  0.5055555555555555
# *****************************************************************************************
# Features Importance using Forward Selection Method
# *****************************************************************************************
# Features obtained from Forward Selection method :
# --------------------------------------
# ['Net Profit GR', 'Alpha GR', 'No. of Trades GR']
# SVR Model fitted using columns obtained from feature importance using ForwardSelection :
# 1
# 1.0
# 1.0
# 2.0
# Values in Same direction -----> -----> 448
# Values in Opposite direction <----- ----->  452
# Percentage of correct direction :  0.49777777777777776
# *****************************************************************************************
# Features Importance using Backward Elimination Method
# *****************************************************************************************
# Features obtained from Backward Elimination method :
# --------------------------------------
# ['No. of Trades GR', 'Alpha GR', 'Net Profit GR']
# SVR Model fitted using columns obtained from feature importance using BackwardElimination :
# 1
# 1.0
# 1.0
# 2.0
# Values in Same direction -----> -----> 448
# Values in Opposite direction <----- ----->  452
# Percentage of correct direction :  0.49777777777777776
# *****************************************************************************************
# Features Importance using f-value
# *****************************************************************************************
# Features obtained from f-values greater than 1 :
# --------------------------------------
# ['Close Price GR', 'No. of Trades GR', 'Alpha GR', 'Beta GR', 'Revenue GR', 'Dividend Value GR', 'Expenditure GR', 'Net Profit GR', 'EPS GR']
# SVR Model fitted using columns obtained from feature importance using FValue :
# 1
# 1.0
# 1.0
# 1.0
# Values in Same direction -----> -----> 453
# Values in Opposite direction <----- ----->  447
# Percentage of correct direction :  0.5033333333333333
# Features obtained from f-values greater than 10 :
# --------------------------------------
# ['Revenue GR', 'Net Profit GR', 'EPS GR']
# SVR Model fitted using columns obtained from feature importance using FValue :
# 1
# 1.0
# 1.0
# 1.0
# Values in Same direction -----> -----> 463
# Values in Opposite direction <----- ----->  437
# Percentage of correct direction :  0.5144444444444445
# Features obtained from f-values greater than 100 :
# --------------------------------------
# []
# Features obtained from f-values greater than 1000 :
# --------------------------------------
# []
# *****************************************************************************************
# Maximum correct direction values are obtained for SVR_FI_Coefficients_0.1 with a percentage of 0.52.
# #################################################################################################################
# For stock :  500209
# #################################################################################################################
# Features Importance using Coefficients
# *****************************************************************************************
# Features obtained from coefficients greater than 0.1 :
# --------------------------------------
# ['High Price GR', 'WAP GR', 'Alpha GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using Coefficients :
# 1
# 1.0
# 41.0
# 41.0
# Values in Same direction -----> -----> 464
# Values in Opposite direction <----- ----->  435
# Percentage of correct direction :  0.5161290322580645
# *****************************************************************************************
# Features Importance using p-value
# *****************************************************************************************
# Features obtained from p-values less than 0.02 :
# -------------------------------------------------
# ['No.of Shares GR', 'Total Turnover (Rs.) GR', 'Alpha GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 1
# 1.0
# 41.0
# 38.0
# Values in Same direction -----> -----> 435
# Values in Opposite direction <----- ----->  464
# Percentage of correct direction :  0.4838709677419355
# Features obtained from p-values less than 0.05 :
# -------------------------------------------------
# ['No.of Shares GR', 'Total Turnover (Rs.) GR', 'Alpha GR', 'Beta GR', 'Net Profit GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 1
# 1.0
# 41.0
# 40.0
# Values in Same direction -----> -----> 446
# Values in Opposite direction <----- ----->  453
# Percentage of correct direction :  0.4961067853170189
# Features obtained from p-values less than 0.1 :
# -------------------------------------------------
# ['No.of Shares GR', 'Total Turnover (Rs.) GR', 'Alpha GR', 'Beta GR', 'Net Profit GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 1
# 1.0
# 41.0
# 40.0
# Values in Same direction -----> -----> 446
# Values in Opposite direction <----- ----->  453
# Percentage of correct direction :  0.4961067853170189
# Features obtained from p-values less than 0.2 :
# -------------------------------------------------
# ['No.of Shares GR', 'Total Turnover (Rs.) GR', 'Alpha GR', 'Beta GR', 'Net Profit GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 1
# 1.0
# 41.0
# 40.0
# Values in Same direction -----> -----> 446
# Values in Opposite direction <----- ----->  453
# Percentage of correct direction :  0.4961067853170189
# *****************************************************************************************
# Features Importance using Forward Selection Method
# *****************************************************************************************
# Features obtained from Forward Selection method :
# --------------------------------------
# ['Beta GR', 'Alpha GR', 'WAP GR', 'No. of Trades GR', 'Spread High-Low GR', 'Net Profit GR']
# SVR Model fitted using columns obtained from feature importance using ForwardSelection :
# 1
# 1.0
# 41.0
# 39.0
# Values in Same direction -----> -----> 438
# Values in Opposite direction <----- ----->  461
# Percentage of correct direction :  0.4872080088987764
# *****************************************************************************************
# Features Importance using Backward Elimination Method
# *****************************************************************************************
# Features obtained from Backward Elimination method :
# --------------------------------------
# ['High Price GR', 'WAP GR', 'No.of Shares GR', 'Total Turnover (Rs.) GR', 'Alpha GR', 'Beta GR', 'Net Profit GR']
# SVR Model fitted using columns obtained from feature importance using BackwardElimination :
# 1
# 1.0
# 41.0
# 35.0
# Values in Same direction -----> -----> 449
# Values in Opposite direction <----- ----->  450
# Percentage of correct direction :  0.4994438264738598
# *****************************************************************************************
# Features Importance using f-value
# *****************************************************************************************
# Features obtained from f-values greater than 1 :
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR', 'No. of Trades GR', 'Spread High-Low GR', 'Alpha GR', 'Beta GR', 'Net Profit GR', 'EPS GR']
# SVR Model fitted using columns obtained from feature importance using FValue :
# 1
# 1.0
# 31.0
# 34.0
# Values in Same direction -----> -----> 463
# Values in Opposite direction <----- ----->  436
# Percentage of correct direction :  0.5150166852057843
# Features obtained from f-values greater than 10 :
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR', 'Alpha GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using FValue :
# 1
# 1.0
# 41.0
# 36.0
# Values in Same direction -----> -----> 456
# Values in Opposite direction <----- ----->  443
# Percentage of correct direction :  0.5072302558398221
# Features obtained from f-values greater than 100 :
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR', 'Alpha GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using FValue :
# 1
# 1.0
# 41.0
# 36.0
# Values in Same direction -----> -----> 456
# Values in Opposite direction <----- ----->  443
# Percentage of correct direction :  0.5072302558398221
# Features obtained from f-values greater than 1000 :
# --------------------------------------
# []
# *****************************************************************************************
# Maximum correct direction values are obtained for SVR_FI_Coefficients_0.1 with a percentage of 0.5161290322580645.
# #################################################################################################################
# For stock :  500325
# #################################################################################################################
# Features Importance using Coefficients
# *****************************************************************************************
# Features obtained from coefficients greater than 0.1 :
# --------------------------------------
# ['Low Price GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using Coefficients :
# 1
# 1.0
# 1.0
# 1.0
# Values in Same direction -----> -----> 435
# Values in Opposite direction <----- ----->  464
# Percentage of correct direction :  0.4838709677419355
# *****************************************************************************************
# Features Importance using p-value
# *****************************************************************************************
# Features obtained from p-values less than 0.02 :
# -------------------------------------------------
# ['Alpha GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 1
# 1.0
# 1.0
# 1.0
# Values in Same direction -----> -----> 422
# Values in Opposite direction <----- ----->  477
# Percentage of correct direction :  0.4694104560622914
# Features obtained from p-values less than 0.05 :
# -------------------------------------------------
# ['Alpha GR', 'Beta GR', 'Revenue GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 1
# 1.0
# 1.0
# 1.0
# Values in Same direction -----> -----> 427
# Values in Opposite direction <----- ----->  472
# Percentage of correct direction :  0.474972191323693
# Features obtained from p-values less than 0.1 :
# -------------------------------------------------
# ['No. of Trades GR', 'Alpha GR', 'Beta GR', 'Revenue GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 1
# 1.0
# 1.0
# 2.0
# Values in Same direction -----> -----> 442
# Values in Opposite direction <----- ----->  457
# Percentage of correct direction :  0.4916573971078977
# Features obtained from p-values less than 0.2 :
# -------------------------------------------------
# ['No. of Trades GR', 'Alpha GR', 'Beta GR', 'Revenue GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 1
# 1.0
# 1.0
# 2.0
# Values in Same direction -----> -----> 442
# Values in Opposite direction <----- ----->  457
# Percentage of correct direction :  0.4916573971078977
# *****************************************************************************************
# Features Importance using Forward Selection Method
# *****************************************************************************************
# Features obtained from Forward Selection method :
# --------------------------------------
# ['Alpha GR', 'Beta GR', 'High Price GR']
# SVR Model fitted using columns obtained from feature importance using ForwardSelection :
# 1
# 1.0
# 1.0
# 2.0
# Values in Same direction -----> -----> 425
# Values in Opposite direction <----- ----->  474
# Percentage of correct direction :  0.4727474972191324
# *****************************************************************************************
# Features Importance using Backward Elimination Method
# *****************************************************************************************
# Features obtained from Backward Elimination method :
# --------------------------------------
# ['Close Price GR', 'Alpha GR', 'Beta GR', 'Revenue GR', 'EPS GR']
# SVR Model fitted using columns obtained from feature importance using BackwardElimination :
# 1
# 1.0
# 1.0
# 3.0
# Values in Same direction -----> -----> 434
# Values in Opposite direction <----- ----->  465
# Percentage of correct direction :  0.4827586206896552
# *****************************************************************************************
# Features Importance using f-value
# *****************************************************************************************
# Features obtained from f-values greater than 1 :
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR', 'Spread High-Low GR', 'Alpha GR', 'Beta GR', 'Revenue GR', 'Net Profit GR', 'EPS GR']
# SVR Model fitted using columns obtained from feature importance using FValue :
# 1
# 1.0
# 1.0
# 1.0
# Values in Same direction -----> -----> 426
# Values in Opposite direction <----- ----->  473
# Percentage of correct direction :  0.4738598442714127
# Features obtained from f-values greater than 10 :
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR', 'Alpha GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using FValue :
# 1
# 1.0
# 1.0
# 1.0
# Values in Same direction -----> -----> 429
# Values in Opposite direction <----- ----->  470
# Percentage of correct direction :  0.4771968854282536
# Features obtained from f-values greater than 100 :
# --------------------------------------
# ['Alpha GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using FValue :
# 1
# 1.0
# 1.0
# 1.0
# Values in Same direction -----> -----> 422
# Values in Opposite direction <----- ----->  477
# Percentage of correct direction :  0.4694104560622914
# Features obtained from f-values greater than 1000 :
# --------------------------------------
# []
# *****************************************************************************************
# Maximum correct direction values are obtained for SVR_FI_PValue_0.2 with a percentage of 0.4916573971078977.
# #################################################################################################################
# For stock :  500680
# #################################################################################################################
# Features Importance using Coefficients
# *****************************************************************************************
# Features obtained from coefficients greater than 0.1 :
# --------------------------------------
# ['Low Price GR', 'WAP GR']
# SVR Model fitted using columns obtained from feature importance using Coefficients :
# 5001
# 5301.0
# 5291.0
# 5296.0
# Values in Same direction -----> -----> 436
# Values in Opposite direction <----- ----->  444
# Percentage of correct direction :  0.4954545454545455
# *****************************************************************************************
# Features Importance using p-value
# *****************************************************************************************
# Features obtained from p-values less than 0.02 :
# -------------------------------------------------
# ['Low Price GR', 'Close Price GR', 'WAP GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 5001
# 4901.0
# 4811.0
# 4818.0
# Values in Same direction -----> -----> 421
# Values in Opposite direction <----- ----->  459
# Percentage of correct direction :  0.4784090909090909
# Features obtained from p-values less than 0.05 :
# -------------------------------------------------
# ['Low Price GR', 'Close Price GR', 'WAP GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 5001
# 4901.0
# 4811.0
# 4818.0
# Values in Same direction -----> -----> 421
# Values in Opposite direction <----- ----->  459
# Percentage of correct direction :  0.4784090909090909
# Features obtained from p-values less than 0.1 :
# -------------------------------------------------
# ['Low Price GR', 'Close Price GR', 'WAP GR', 'No. of Trades GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 4001
# 3801.0
# 3801.0
# 3801.0
# Values in Same direction -----> -----> 443
# Values in Opposite direction <----- ----->  437
# Percentage of correct direction :  0.5034090909090909
# Features obtained from p-values less than 0.2 :
# -------------------------------------------------
# ['Low Price GR', 'Close Price GR', 'WAP GR', 'No. of Trades GR', 'Beta GR', 'Net Profit GR', 'EPS GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 3001
# 2701.0
# 2641.0
# 2641.0
# Values in Same direction -----> -----> 438
# Values in Opposite direction <----- ----->  442
# Percentage of correct direction :  0.49772727272727274
# *****************************************************************************************
# Features Importance using Forward Selection Method
# *****************************************************************************************
# Features obtained from Forward Selection method :
# --------------------------------------
# ['Low Price GR', 'No. of Trades GR']
# SVR Model fitted using columns obtained from feature importance using ForwardSelection :
# 2001
# 2301.0
# 2291.0
# 2291.0
# Values in Same direction -----> -----> 437
# Values in Opposite direction <----- ----->  443
# Percentage of correct direction :  0.4965909090909091
# *****************************************************************************************
# Features Importance using Backward Elimination Method
# *****************************************************************************************
# Features obtained from Backward Elimination method :
# --------------------------------------
# ['High Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR', 'No. of Trades GR']
# SVR Model fitted using columns obtained from feature importance using BackwardElimination :
# 2001
# 2001.0
# 2001.0
# 2001.0
# Values in Same direction -----> -----> 440
# Values in Opposite direction <----- ----->  440
# Percentage of correct direction :  0.5
# *****************************************************************************************
# Features Importance using f-value
# *****************************************************************************************
# Features obtained from f-values greater than 1 :
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR', 'No.of Shares GR', 'No. of Trades GR', 'Total Turnover (Rs.) GR', 'Deliverable Quantity GR', 'Dividend Value GR']
# SVR Model fitted using columns obtained from feature importance using FValue :
# 1
# 1.0
# 1.0
# 1.0
# Values in Same direction -----> -----> 452
# Values in Opposite direction <----- ----->  428
# Percentage of correct direction :  0.5136363636363637
# Features obtained from f-values greater than 10 :
# --------------------------------------
# ['High Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR']
# SVR Model fitted using columns obtained from feature importance using FValue :
# 9001
# 9501.0
# 9501.0
# 9509.0
# Values in Same direction -----> -----> 427
# Values in Opposite direction <----- ----->  453
# Percentage of correct direction :  0.48522727272727273
# Features obtained from f-values greater than 100 :
# --------------------------------------
# []
# Features obtained from f-values greater than 1000 :
# --------------------------------------
# []
# *****************************************************************************************
# Maximum correct direction values are obtained for SVR_FI_FValue_1 with a percentage of 0.5136363636363637.
# #################################################################################################################
# For stock :  507685
# #################################################################################################################
# Features Importance using Coefficients
# *****************************************************************************************
# Features obtained from coefficients greater than 0.1 :
# --------------------------------------
# ['High Price GR', 'Close Price GR', 'WAP GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using Coefficients :
# 6001
# 6201.0
# 6121.0
# 6115.0
# Values in Same direction -----> -----> 433
# Values in Opposite direction <----- ----->  463
# Percentage of correct direction :  0.48325892857142855
# *****************************************************************************************
# Features Importance using p-value
# *****************************************************************************************
# Features obtained from p-values less than 0.02 :
# -------------------------------------------------
# ['High Price GR', 'WAP GR', 'Alpha GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 1
# 101.0
# 111.0
# 106.0
# Values in Same direction -----> -----> 425
# Values in Opposite direction <----- ----->  471
# Percentage of correct direction :  0.47433035714285715
# Features obtained from p-values less than 0.05 :
# -------------------------------------------------
# ['High Price GR', 'WAP GR', 'Alpha GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 1
# 101.0
# 111.0
# 106.0
# Values in Same direction -----> -----> 425
# Values in Opposite direction <----- ----->  471
# Percentage of correct direction :  0.47433035714285715
# Features obtained from p-values less than 0.1 :
# -------------------------------------------------
# ['High Price GR', 'WAP GR', 'Spread Close-Open GR', 'Alpha GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 1
# 101.0
# 151.0
# 151.0
# Values in Same direction -----> -----> 467
# Values in Opposite direction <----- ----->  429
# Percentage of correct direction :  0.5212053571428571
# Features obtained from p-values less than 0.2 :
# -------------------------------------------------
# ['High Price GR', 'WAP GR', '% Deli. Qty to Traded Qty GR', 'Spread Close-Open GR', 'Alpha GR', 'Beta GR', 'Net Profit GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 1
# 201.0
# 171.0
# 165.0
# Values in Same direction -----> -----> 471
# Values in Opposite direction <----- ----->  425
# Percentage of correct direction :  0.5256696428571429
# *****************************************************************************************
# Features Importance using Forward Selection Method
# *****************************************************************************************
# Features obtained from Forward Selection method :
# --------------------------------------
# ['High Price GR', 'Beta GR', 'Alpha GR', 'No. of Trades GR', 'WAP GR', 'Close Price GR', 'Open Price GR']
# SVR Model fitted using columns obtained from feature importance using ForwardSelection :
# 1
# 101.0
# 111.0
# 107.0
# Values in Same direction -----> -----> 437
# Values in Opposite direction <----- ----->  459
# Percentage of correct direction :  0.4877232142857143
# *****************************************************************************************
# Features Importance using Backward Elimination Method
# *****************************************************************************************
# Features obtained from Backward Elimination method :
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'Close Price GR', 'WAP GR', 'No. of Trades GR', 'Alpha GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using BackwardElimination :
# 1
# 101.0
# 111.0
# 107.0
# Values in Same direction -----> -----> 437
# Values in Opposite direction <----- ----->  459
# Percentage of correct direction :  0.4877232142857143
# *****************************************************************************************
# Features Importance using f-value
# *****************************************************************************************
# Features obtained from f-values greater than 1 :
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR', 'No. of Trades GR', 'Spread High-Low GR', 'Alpha GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using FValue :
# 1
# 101.0
# 101.0
# 110.0
# Values in Same direction -----> -----> 446
# Values in Opposite direction <----- ----->  450
# Percentage of correct direction :  0.49776785714285715
# Features obtained from f-values greater than 10 :
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR', 'Alpha GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using FValue :
# 1
# 101.0
# 121.0
# 117.0
# Values in Same direction -----> -----> 426
# Values in Opposite direction <----- ----->  470
# Percentage of correct direction :  0.47544642857142855
# Features obtained from f-values greater than 100 :
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR', 'Alpha GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using FValue :
# 1
# 101.0
# 121.0
# 117.0
# Values in Same direction -----> -----> 426
# Values in Opposite direction <----- ----->  470
# Percentage of correct direction :  0.47544642857142855
# Features obtained from f-values greater than 1000 :
# --------------------------------------
# []
# *****************************************************************************************
# Maximum correct direction values are obtained for SVR_FI_PValue_0.2 with a percentage of 0.5256696428571429.
# #################################################################################################################
# For stock :  530965
# #################################################################################################################
# Features Importance using Coefficients
# *****************************************************************************************
# Features obtained from coefficients greater than 0.1 :
# --------------------------------------
# ['Open Price GR', 'Low Price GR', 'WAP GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using Coefficients :
# 1
# 101.0
# 41.0
# 40.0
# Values in Same direction -----> -----> 440
# Values in Opposite direction <----- ----->  455
# Percentage of correct direction :  0.49162011173184356
# *****************************************************************************************
# Features Importance using p-value
# *****************************************************************************************
# Features obtained from p-values less than 0.02 :
# -------------------------------------------------
# ['Open Price GR', 'Alpha GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 1
# 1.0
# 11.0
# 14.0
# Values in Same direction -----> -----> 442
# Values in Opposite direction <----- ----->  453
# Percentage of correct direction :  0.49385474860335193
# Features obtained from p-values less than 0.05 :
# -------------------------------------------------
# ['Open Price GR', 'Alpha GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 1
# 1.0
# 11.0
# 14.0
# Values in Same direction -----> -----> 442
# Values in Opposite direction <----- ----->  453
# Percentage of correct direction :  0.49385474860335193
# Features obtained from p-values less than 0.1 :
# -------------------------------------------------
# ['Open Price GR', 'Alpha GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 1
# 1.0
# 11.0
# 14.0
# Values in Same direction -----> -----> 442
# Values in Opposite direction <----- ----->  453
# Percentage of correct direction :  0.49385474860335193
# Features obtained from p-values less than 0.2 :
# -------------------------------------------------
# ['Open Price GR', 'Low Price GR', 'WAP GR', 'No.of Shares GR', 'Total Turnover (Rs.) GR', 'Alpha GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 1
# 101.0
# 61.0
# 61.0
# Values in Same direction -----> -----> 448
# Values in Opposite direction <----- ----->  447
# Percentage of correct direction :  0.5005586592178771
# *****************************************************************************************
# Features Importance using Forward Selection Method
# *****************************************************************************************
# Features obtained from Forward Selection method :
# --------------------------------------
# ['Beta GR', 'Open Price GR', 'Alpha GR']
# SVR Model fitted using columns obtained from feature importance using ForwardSelection :
# 1
# 1.0
# 11.0
# 14.0
# Values in Same direction -----> -----> 442
# Values in Opposite direction <----- ----->  453
# Percentage of correct direction :  0.49385474860335193
# *****************************************************************************************
# Features Importance using Backward Elimination Method
# *****************************************************************************************
# Features obtained from Backward Elimination method :
# --------------------------------------
# ['Open Price GR', 'Low Price GR', 'No.of Shares GR', 'Total Turnover (Rs.) GR', 'Deliverable Quantity GR', '% Deli. Qty to Traded Qty GR', 'Alpha GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using BackwardElimination :
# 1
# 1.0
# 31.0
# 39.0
# Values in Same direction -----> -----> 464
# Values in Opposite direction <----- ----->  431
# Percentage of correct direction :  0.5184357541899441
# *****************************************************************************************
# Features Importance using f-value
# *****************************************************************************************
# Features obtained from f-values greater than 1 :
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR', 'No. of Trades GR', '% Deli. Qty to Traded Qty GR', 'Spread High-Low GR', 'Alpha GR', 'Beta GR', 'Revenue GR', 'Dividend Value GR']
# SVR Model fitted using columns obtained from feature importance using FValue :
# 1
# 1.0
# 31.0
# 36.0
# Values in Same direction -----> -----> 448
# Values in Opposite direction <----- ----->  447
# Percentage of correct direction :  0.5005586592178771
# Features obtained from f-values greater than 10 :
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR', 'Alpha GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using FValue :
# 1
# 1.0
# 51.0
# 48.0
# Values in Same direction -----> -----> 445
# Values in Opposite direction <----- ----->  450
# Percentage of correct direction :  0.4972067039106145
# Features obtained from f-values greater than 100 :
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using FValue :
# 1
# 101.0
# 61.0
# 61.0
# Values in Same direction -----> -----> 450
# Values in Opposite direction <----- ----->  445
# Percentage of correct direction :  0.5027932960893855
# Features obtained from f-values greater than 1000 :
# --------------------------------------
# []
# *****************************************************************************************
# Maximum correct direction values are obtained for SVR_FI_BackwardElimination_ with a percentage of 0.5184357541899441.
# #################################################################################################################
# For stock :  532174
# #################################################################################################################
# Features Importance using Coefficients
# *****************************************************************************************
# Features obtained from coefficients greater than 0.1 :
# --------------------------------------
# ['High Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using Coefficients :
# 6001
# 5801.0
# 5821.0
# 5812.0
# Values in Same direction -----> -----> 437
# Values in Opposite direction <----- ----->  461
# Percentage of correct direction :  0.4866369710467706
# *****************************************************************************************
# Features Importance using p-value
# *****************************************************************************************
# Features obtained from p-values less than 0.02 :
# -------------------------------------------------
# ['Alpha GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 8001
# 8701.0
# 8681.0
# 8681.0
# Values in Same direction -----> -----> 459
# Values in Opposite direction <----- ----->  439
# Percentage of correct direction :  0.5111358574610245
# Features obtained from p-values less than 0.05 :
# -------------------------------------------------
# ['Open Price GR', 'Alpha GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 9001
# 9101.0
# 9161.0
# 9161.0
# Values in Same direction -----> -----> 427
# Values in Opposite direction <----- ----->  471
# Percentage of correct direction :  0.4755011135857461
# Features obtained from p-values less than 0.1 :
# -------------------------------------------------
# ['Open Price GR', 'Alpha GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 9001
# 9101.0
# 9161.0
# 9161.0
# Values in Same direction -----> -----> 427
# Values in Opposite direction <----- ----->  471
# Percentage of correct direction :  0.4755011135857461
# Features obtained from p-values less than 0.2 :
# -------------------------------------------------
# ['Open Price GR', 'High Price GR', 'Spread High-Low GR', 'Spread Close-Open GR', 'Alpha GR', 'Beta GR', 'Expenditure GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 1001
# 301.0
# 331.0
# 336.0
# Values in Same direction -----> -----> 442
# Values in Opposite direction <----- ----->  456
# Percentage of correct direction :  0.4922048997772829
# *****************************************************************************************
# Features Importance using Forward Selection Method
# *****************************************************************************************
# Features obtained from Forward Selection method :
# --------------------------------------
# ['Beta GR', 'Close Price GR', 'WAP GR', 'Spread High-Low GR', 'Alpha GR', 'High Price GR', 'Low Price GR']
# SVR Model fitted using columns obtained from feature importance using ForwardSelection :
# 4001
# 3901.0
# 3991.0
# 3997.0
# Values in Same direction -----> -----> 441
# Values in Opposite direction <----- ----->  457
# Percentage of correct direction :  0.4910913140311804
# *****************************************************************************************
# Features Importance using Backward Elimination Method
# *****************************************************************************************
# Features obtained from Backward Elimination method :
# --------------------------------------
# ['High Price GR', 'Low Price GR', 'WAP GR', 'No.of Shares GR', 'No. of Trades GR', 'Total Turnover (Rs.) GR', 'Spread High-Low GR', 'Alpha GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using BackwardElimination :
# 4001
# 4001.0
# 3961.0
# 3961.0
# Values in Same direction -----> -----> 441
# Values in Opposite direction <----- ----->  457
# Percentage of correct direction :  0.4910913140311804
# *****************************************************************************************
# Features Importance using f-value
# *****************************************************************************************
# Features obtained from f-values greater than 1 :
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR', 'No.of Shares GR', 'Spread High-Low GR', 'Alpha GR', 'Beta GR', 'Revenue GR', 'Dividend Value GR', 'Income GR', 'Expenditure GR']
# SVR Model fitted using columns obtained from feature importance using FValue :
# 5001
# 4601.0
# 4551.0
# 4548.0
# Values in Same direction -----> -----> 443
# Values in Opposite direction <----- ----->  455
# Percentage of correct direction :  0.4933184855233853
# Features obtained from f-values greater than 10 :
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR', 'Spread High-Low GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using FValue :
# 5001
# 4901.0
# 4841.0
# 4837.0
# Values in Same direction -----> -----> 432
# Values in Opposite direction <----- ----->  466
# Percentage of correct direction :  0.48106904231625836
# Features obtained from f-values greater than 100 :
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using FValue :
# 5001
# 4801.0
# 4721.0
# 4721.0
# Values in Same direction -----> -----> 442
# Values in Opposite direction <----- ----->  456
# Percentage of correct direction :  0.4922048997772829
# Features obtained from f-values greater than 1000 :
# --------------------------------------
# ['Beta GR']
# SVR Model fitted using columns obtained from feature importance using FValue :
# 8001
# 8401.0
# 8401.0
# 8408.0
# Values in Same direction -----> -----> 475
# Values in Opposite direction <----- ----->  423
# Percentage of correct direction :  0.5289532293986637
# *****************************************************************************************
# Maximum correct direction values are obtained for SVR_FI_FValue_1000 with a percentage of 0.5289532293986637.
# #################################################################################################################
# For stock :  532210
# #################################################################################################################
# Features Importance using Coefficients
# *****************************************************************************************
# Features obtained from coefficients greater than 0.1 :
# --------------------------------------
# []
# *****************************************************************************************
# Features Importance using p-value
# *****************************************************************************************
# Features obtained from p-values less than 0.02 :
# -------------------------------------------------
# []
# Features obtained from p-values less than 0.05 :
# -------------------------------------------------
# ['Open Price GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 1001
# 901.0
# 871.0
# 879.0
# Values in Same direction -----> -----> 416
# Values in Opposite direction <----- ----->  452
# Percentage of correct direction :  0.4792626728110599
# Features obtained from p-values less than 0.1 :
# -------------------------------------------------
# ['Open Price GR', 'High Price GR', 'No. of Trades GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 1
# 201.0
# 131.0
# 131.0
# Values in Same direction -----> -----> 418
# Values in Opposite direction <----- ----->  450
# Percentage of correct direction :  0.4815668202764977
# Features obtained from p-values less than 0.2 :
# -------------------------------------------------
# ['Open Price GR', 'High Price GR', 'No. of Trades GR', 'Alpha GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 1
# 1.0
# 11.0
# 13.0
# Values in Same direction -----> -----> 414
# Values in Opposite direction <----- ----->  454
# Percentage of correct direction :  0.4769585253456221
# *****************************************************************************************
# Features Importance using Forward Selection Method
# *****************************************************************************************
# Features obtained from Forward Selection method :
# --------------------------------------
# ['No. of Trades GR', 'Open Price GR']
# SVR Model fitted using columns obtained from feature importance using ForwardSelection :
# 1
# 301.0
# 231.0
# 231.0
# Values in Same direction -----> -----> 412
# Values in Opposite direction <----- ----->  456
# Percentage of correct direction :  0.47465437788018433
# *****************************************************************************************
# Features Importance using Backward Elimination Method
# *****************************************************************************************
# Features obtained from Backward Elimination method :
# --------------------------------------
# ['Open Price GR', 'No. of Trades GR']
# SVR Model fitted using columns obtained from feature importance using BackwardElimination :
# 1
# 301.0
# 231.0
# 231.0
# Values in Same direction -----> -----> 412
# Values in Opposite direction <----- ----->  456
# Percentage of correct direction :  0.47465437788018433
# *****************************************************************************************
# Features Importance using f-value
# *****************************************************************************************
# Features obtained from f-values greater than 1 :
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR', 'No. of Trades GR', 'Beta GR', 'Income GR', 'Expenditure GR', 'Net Profit GR', 'EPS GR']
# SVR Model fitted using columns obtained from feature importance using FValue :
# 1
# 1.0
# 1.0
# 1.0
# Values in Same direction -----> -----> 424
# Values in Opposite direction <----- ----->  444
# Percentage of correct direction :  0.48847926267281105
# Features obtained from f-values greater than 10 :
# --------------------------------------
# []
# Features obtained from f-values greater than 100 :
# --------------------------------------
# []
# Features obtained from f-values greater than 1000 :
# --------------------------------------
# []
# *****************************************************************************************
# Maximum correct direction values are obtained for SVR_FI_FValue_1 with a percentage of 0.48847926267281105.
# #################################################################################################################
# For stock :  532540
# #################################################################################################################
# Features Importance using Coefficients
# *****************************************************************************************
# Features obtained from coefficients greater than 0.1 :
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'Close Price GR', 'WAP GR']
# SVR Model fitted using columns obtained from feature importance using Coefficients :
# 1
# 1.0
# 1.0
# 1.0
# Values in Same direction -----> -----> 442
# Values in Opposite direction <----- ----->  390
# Percentage of correct direction :  0.53125
# *****************************************************************************************
# Features Importance using p-value
# *****************************************************************************************
# Features obtained from p-values less than 0.02 :
# -------------------------------------------------
# ['Open Price GR', 'Close Price GR', 'Alpha GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 1
# 1.0
# 1.0
# 1.0
# Values in Same direction -----> -----> 440
# Values in Opposite direction <----- ----->  392
# Percentage of correct direction :  0.5288461538461539
# Features obtained from p-values less than 0.05 :
# -------------------------------------------------
# ['Open Price GR', 'High Price GR', 'Close Price GR', 'Spread High-Low GR', 'Alpha GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 1
# 1.0
# 61.0
# 60.0
# Values in Same direction -----> -----> 451
# Values in Opposite direction <----- ----->  381
# Percentage of correct direction :  0.5420673076923077
# Features obtained from p-values less than 0.1 :
# -------------------------------------------------
# ['Open Price GR', 'High Price GR', 'Close Price GR', 'Spread High-Low GR', 'Spread Close-Open GR', 'Alpha GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 1
# 1.0
# 11.0
# 8.0
# Values in Same direction -----> -----> 447
# Values in Opposite direction <----- ----->  385
# Percentage of correct direction :  0.5372596153846154
# Features obtained from p-values less than 0.2 :
# -------------------------------------------------
# ['Open Price GR', 'High Price GR', 'Close Price GR', 'Spread High-Low GR', 'Spread Close-Open GR', 'Alpha GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 1
# 1.0
# 11.0
# 8.0
# Values in Same direction -----> -----> 447
# Values in Opposite direction <----- ----->  385
# Percentage of correct direction :  0.5372596153846154
# *****************************************************************************************
# Features Importance using Forward Selection Method
# *****************************************************************************************
# Features obtained from Forward Selection method :
# --------------------------------------
# ['WAP GR', 'Open Price GR', 'Close Price GR', 'Alpha GR']
# SVR Model fitted using columns obtained from feature importance using ForwardSelection :
# 1
# 1.0
# 1.0
# 2.0
# Values in Same direction -----> -----> 436
# Values in Opposite direction <----- ----->  396
# Percentage of correct direction :  0.5240384615384616
# *****************************************************************************************
# Features Importance using Backward Elimination Method
# *****************************************************************************************
# Features obtained from Backward Elimination method :
# --------------------------------------
# ['Open Price GR', 'Close Price GR', 'Alpha GR']
# SVR Model fitted using columns obtained from feature importance using BackwardElimination :
# 1
# 1.0
# 1.0
# 1.0
# Values in Same direction -----> -----> 440
# Values in Opposite direction <----- ----->  392
# Percentage of correct direction :  0.5288461538461539
# *****************************************************************************************
# Features Importance using f-value
# *****************************************************************************************
# Features obtained from f-values greater than 1 :
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR', 'No.of Shares GR', 'No. of Trades GR', 'Total Turnover (Rs.) GR', 'Alpha GR']
# SVR Model fitted using columns obtained from feature importance using FValue :
# 1
# 1.0
# 1.0
# 1.0
# Values in Same direction -----> -----> 440
# Values in Opposite direction <----- ----->  392
# Percentage of correct direction :  0.5288461538461539
# Features obtained from f-values greater than 10 :
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR']
# SVR Model fitted using columns obtained from feature importance using FValue :
# 1
# 1.0
# 1.0
# 1.0
# Values in Same direction -----> -----> 453
# Values in Opposite direction <----- ----->  379
# Percentage of correct direction :  0.5444711538461539
# Features obtained from f-values greater than 100 :
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR']
# SVR Model fitted using columns obtained from feature importance using FValue :
# 1
# 1.0
# 1.0
# 1.0
# Values in Same direction -----> -----> 453
# Values in Opposite direction <----- ----->  379
# Percentage of correct direction :  0.5444711538461539
# Features obtained from f-values greater than 1000 :
# --------------------------------------
# []
# *****************************************************************************************
# Maximum correct direction values are obtained for SVR_FI_FValue_100 with a percentage of 0.5444711538461539.
# #################################################################################################################
# Wall time: 1h 35min 40s

# %%
for name,table in tables.items():
    print(table)
# Out:
# +------------------------------------------------------------------------------------------------------------------------------------+
# |                                                                SVR                                                                 |
# +--------------------------------------+----------------------+------------+-----------+----------+----------+-----------+-----------+
# |               Company                |        Method        | Percentage | r^2_score | Mean_SE  | Mean_AE  | Median_AE |    EVS    |
# +--------------------------------------+----------------------+------------+-----------+----------+----------+-----------+-----------+
# |             500112-SBIN              |   Coefficients 0.1   |  0.48441   |  0.015689 | 0.084242 | 0.027491 |  0.012696 |  0.016957 |
# |             500112-SBIN              |     PValue 0.02      |  0.48441   |  0.013394 | 0.084439 | 0.027335 |  0.012641 |  0.014695 |
# |             500112-SBIN              |     PValue 0.05      |  0.502227  | -0.001091 | 0.085678 | 0.028428 |  0.012588 |  -3.2e-05 |
# |             500112-SBIN              |      PValue 0.1      |  0.492205  |  0.002575 | 0.085365 | 0.028348 |  0.01264  |  0.003618 |
# |             500112-SBIN              |      PValue 0.2      |  0.494432  |  0.004017 | 0.085241 | 0.028332 |  0.01264  |  0.005076 |
# |             500112-SBIN              |  ForwardSelection    |  0.502227  |  0.011494 | 0.084601 | 0.028196 |  0.012661 |  0.012554 |
# |             500112-SBIN              | BackwardElimination  |  0.501114  |  0.011308 | 0.084617 | 0.028206 |  0.012687 |  0.012378 |
# |             500112-SBIN              |       FValue 1       |  0.488864  |  0.019918 | 0.08388  | 0.027349 |  0.012698 |  0.021278 |
# |             500112-SBIN              |      FValue 10       |  0.488864  |  0.019345 | 0.083929 | 0.027314 |  0.012728 |  0.02065  |
# |             500112-SBIN              |      FValue 100      |  0.504454  |  0.01261  | 0.084506 | 0.027363 |  0.012753 |  0.013941 |
# |             500112-SBIN              |     FValue 1000      |  0.483296  |  0.012253 | 0.084536 | 0.027347 |  0.012618 |  0.013556 |
# |         500180-HDFC Bank Ltd         |   Coefficients 0.1   |  0.532887  | -0.077675 | 0.021313 | 0.018746 |  0.00791  | -0.076281 |
# |         500180-HDFC Bank Ltd         |     PValue 0.02      |  0.537347  | -0.152522 | 0.022793 | 0.018918 |  0.007913 | -0.151041 |
# |         500180-HDFC Bank Ltd         |     PValue 0.05      |  0.537347  | -0.152522 | 0.022793 | 0.018918 |  0.007913 | -0.151041 |
# |         500180-HDFC Bank Ltd         |      PValue 0.1      |  0.537347  | -0.067984 | 0.021121 | 0.018723 |  0.007922 | -0.066619 |
# |         500180-HDFC Bank Ltd         |      PValue 0.2      |  0.478261  | -0.077661 | 0.021312 | 0.018767 |  0.008058 | -0.076435 |
# |         500180-HDFC Bank Ltd         |  ForwardSelection    |  0.508361  | -0.125751 | 0.022263 | 0.019003 |  0.008199 | -0.124417 |
# |         500180-HDFC Bank Ltd         | BackwardElimination  |  0.502787  | -0.099145 | 0.021737 | 0.019074 |  0.008412 | -0.097931 |
# |         500180-HDFC Bank Ltd         |       FValue 1       |  0.511706  | -0.092053 | 0.021597 | 0.018972 |  0.008315 |  -0.09074 |
# |         500180-HDFC Bank Ltd         |      FValue 10       |  0.537347  | -0.152522 | 0.022793 | 0.018918 |  0.007913 | -0.151041 |
# |         500180-HDFC Bank Ltd         |      FValue 100      |  0.537347  | -0.152522 | 0.022793 | 0.018918 |  0.007913 | -0.151041 |
# |         500180-HDFC Bank Ltd         |     FValue 1000      |  0.540691  | -0.151677 | 0.022776 | 0.018921 |  0.007953 | -0.150252 |
# |       500182-HERO MOTOCORP LTD       |   Coefficients 0.1   |    0.52    |  0.002893 | 0.000425 | 0.014163 |  0.009763 |  0.004272 |
# |       500182-HERO MOTOCORP LTD       |     PValue 0.02      |  0.482222  | -0.006204 | 0.000428 | 0.01424  |  0.009884 | -0.003048 |
# |       500182-HERO MOTOCORP LTD       |     PValue 0.05      |    0.5     | -0.004203 | 0.000428 | 0.014221 |  0.009908 | -0.001961 |
# |       500182-HERO MOTOCORP LTD       |      PValue 0.1      |  0.495556  | -0.004646 | 0.000428 | 0.014229 |  0.009922 | -0.002457 |
# |       500182-HERO MOTOCORP LTD       |      PValue 0.2      |  0.505556  | -0.005881 | 0.000428 | 0.014231 |  0.009928 | -0.003195 |
# |       500182-HERO MOTOCORP LTD       |  ForwardSelection    |  0.497778  |  0.000884 | 0.000425 | 0.014182 |  0.009748 |  0.003169 |
# |       500182-HERO MOTOCORP LTD       | BackwardElimination  |  0.497778  |  0.000884 | 0.000425 | 0.014182 |  0.009748 |  0.003169 |
# |       500182-HERO MOTOCORP LTD       |       FValue 1       |  0.503333  | -0.001503 | 0.000426 | 0.014205 |  0.009702 | -0.000318 |
# |       500182-HERO MOTOCORP LTD       |      FValue 10       |  0.514444  |  0.002536 | 0.000425 | 0.014162 |  0.009865 |  0.004097 |
# |          500209-INFOSYS LTD          |   Coefficients 0.1   |  0.516129  |  0.016132 | 0.001977 | 0.015645 |  0.009821 |  0.016707 |
# |          500209-INFOSYS LTD          |     PValue 0.02      |  0.483871  | -0.023731 | 0.002057 | 0.015944 |  0.009753 | -0.023389 |
# |          500209-INFOSYS LTD          |     PValue 0.05      |  0.496107  | -0.020244 | 0.00205  | 0.015925 |  0.009705 | -0.019797 |
# |          500209-INFOSYS LTD          |      PValue 0.1      |  0.496107  | -0.020244 | 0.00205  | 0.015925 |  0.009705 | -0.019797 |
# |          500209-INFOSYS LTD          |      PValue 0.2      |  0.496107  | -0.020244 | 0.00205  | 0.015925 |  0.009705 | -0.019797 |
# |          500209-INFOSYS LTD          |  ForwardSelection    |  0.487208  | -0.024888 | 0.00206  | 0.015867 |  0.009969 | -0.024825 |
# |          500209-INFOSYS LTD          | BackwardElimination  |  0.499444  | -0.023604 | 0.002057 | 0.015931 |  0.009716 | -0.023198 |
# |          500209-INFOSYS LTD          |       FValue 1       |  0.515017  |  0.000593 | 0.002008 | 0.015732 |  0.009893 |  0.000676 |
# |          500209-INFOSYS LTD          |      FValue 10       |  0.50723   |  0.017038 | 0.001975 | 0.015628 |  0.009738 |  0.017211 |
# |          500209-INFOSYS LTD          |      FValue 100      |  0.50723   |  0.017038 | 0.001975 | 0.015628 |  0.009738 |  0.017211 |
# |    500325-RELIANCE INDUSTRIES LTD    |   Coefficients 0.1   |  0.483871  | -0.025017 | 0.00204  | 0.016855 |  0.011456 | -0.023992 |
# |    500325-RELIANCE INDUSTRIES LTD    |     PValue 0.02      |  0.46941   | -0.029324 | 0.002048 | 0.016868 |  0.011576 |  -0.02861 |
# |    500325-RELIANCE INDUSTRIES LTD    |     PValue 0.05      |  0.474972  | -0.022712 | 0.002035 | 0.016865 |  0.011653 | -0.021879 |
# |    500325-RELIANCE INDUSTRIES LTD    |      PValue 0.1      |  0.491657  | -0.034561 | 0.002059 | 0.016994 |  0.011586 | -0.033974 |
# |    500325-RELIANCE INDUSTRIES LTD    |      PValue 0.2      |  0.491657  | -0.034561 | 0.002059 | 0.016994 |  0.011586 | -0.033974 |
# |    500325-RELIANCE INDUSTRIES LTD    |  ForwardSelection    |  0.472747  | -0.021091 | 0.002032 | 0.016864 |  0.011498 | -0.020223 |
# |    500325-RELIANCE INDUSTRIES LTD    | BackwardElimination  |  0.482759  | -0.030577 | 0.002051 | 0.016865 |  0.011673 | -0.029792 |
# |    500325-RELIANCE INDUSTRIES LTD    |       FValue 1       |  0.47386   | -0.043962 | 0.002077 | 0.016924 |  0.011412 | -0.043037 |
# |    500325-RELIANCE INDUSTRIES LTD    |      FValue 10       |  0.477197  | -0.038279 | 0.002066 | 0.016892 |  0.011436 | -0.037245 |
# |    500325-RELIANCE INDUSTRIES LTD    |      FValue 100      |  0.46941   | -0.029324 | 0.002048 | 0.016868 |  0.011576 |  -0.02861 |
# |          500680-PFIZER LTD           |   Coefficients 0.1   |  0.495455  |  0.004281 | 0.00043  | 0.012291 |  0.008223 |  0.004582 |
# |          500680-PFIZER LTD           |     PValue 0.02      |  0.478409  |  0.003382 | 0.00043  | 0.012303 |  0.008269 |  0.003875 |
# |          500680-PFIZER LTD           |     PValue 0.05      |  0.478409  |  0.003382 | 0.00043  | 0.012303 |  0.008269 |  0.003875 |
# |          500680-PFIZER LTD           |      PValue 0.1      |  0.503409  | -0.065989 | 0.00046  | 0.012453 |  0.008471 |  -0.06502 |
# |          500680-PFIZER LTD           |      PValue 0.2      |  0.497727  | -0.280062 | 0.000553 | 0.012652 |  0.008521 | -0.278281 |
# |          500680-PFIZER LTD           |  ForwardSelection    |  0.496591  | -0.094275 | 0.000473 | 0.012484 |  0.008527 | -0.093172 |
# |          500680-PFIZER LTD           | BackwardElimination  |    0.5     | -0.077924 | 0.000466 | 0.012478 |  0.008484 |  -0.07653 |
# |          500680-PFIZER LTD           |       FValue 1       |  0.513636  | -0.026022 | 0.000443 | 0.012519 |  0.008516 | -0.024944 |
# |          500680-PFIZER LTD           |      FValue 10       |  0.485227  |  0.004177 | 0.00043  | 0.012311 |  0.008227 |  0.004896 |
# |           507685-WIPRO LTD           |   Coefficients 0.1   |  0.483259  | -0.004231 | 0.000526 | 0.014249 |  0.009785 | -0.003556 |
# |           507685-WIPRO LTD           |     PValue 0.02      |  0.47433   | -0.004481 | 0.000527 | 0.014258 |  0.009575 | -0.003872 |
# |           507685-WIPRO LTD           |     PValue 0.05      |  0.47433   | -0.004481 | 0.000527 | 0.014258 |  0.009575 | -0.003872 |
# |           507685-WIPRO LTD           |      PValue 0.1      |  0.521205  | -0.005461 | 0.000527 | 0.014275 |  0.009698 | -0.005455 |
# |           507685-WIPRO LTD           |      PValue 0.2      |  0.52567   | -0.010078 | 0.000529 | 0.014313 |  0.009708 | -0.010077 |
# |           507685-WIPRO LTD           |  ForwardSelection    |  0.487723  |  -1.62054 | 0.001374 | 0.015123 |  0.009794 |  -1.62046 |
# |           507685-WIPRO LTD           | BackwardElimination  |  0.487723  |  -1.62054 | 0.001374 | 0.015123 |  0.009794 |  -1.62046 |
# |           507685-WIPRO LTD           |       FValue 1       |  0.497768  | -1.495265 | 0.001308 | 0.015072 |  0.009669 | -1.494421 |
# |           507685-WIPRO LTD           |      FValue 10       |  0.475446  | -0.006128 | 0.000527 | 0.014264 |  0.009762 | -0.005605 |
# |           507685-WIPRO LTD           |      FValue 100      |  0.475446  | -0.006128 | 0.000527 | 0.014264 |  0.009762 | -0.005605 |
# |  530965-INDIAN OIL CORPORATION LTD   |   Coefficients 0.1   |  0.49162   |  0.107575 | 0.000707 | 0.016324 |  0.01163  |  0.110347 |
# |  530965-INDIAN OIL CORPORATION LTD   |     PValue 0.02      |  0.493855  |  0.185367 | 0.000646 | 0.016177 |  0.011531 |  0.188654 |
# |  530965-INDIAN OIL CORPORATION LTD   |     PValue 0.05      |  0.493855  |  0.185367 | 0.000646 | 0.016177 |  0.011531 |  0.188654 |
# |  530965-INDIAN OIL CORPORATION LTD   |      PValue 0.1      |  0.493855  |  0.185367 | 0.000646 | 0.016177 |  0.011531 |  0.188654 |
# |  530965-INDIAN OIL CORPORATION LTD   |      PValue 0.2      |  0.500559  |  0.152448 | 0.000672 | 0.01634  |  0.011541 |  0.155235 |
# |  530965-INDIAN OIL CORPORATION LTD   |  ForwardSelection    |  0.493855  |  0.185367 | 0.000646 | 0.016177 |  0.011531 |  0.188654 |
# |  530965-INDIAN OIL CORPORATION LTD   | BackwardElimination  |  0.518436  |  0.049245 | 0.000753 | 0.016613 |  0.011293 |  0.051413 |
# |  530965-INDIAN OIL CORPORATION LTD   |       FValue 1       |  0.500559  |  0.119028 | 0.000698 | 0.016306 |  0.011447 |  0.121367 |
# |  530965-INDIAN OIL CORPORATION LTD   |      FValue 10       |  0.497207  |  0.105528 | 0.000709 | 0.016322 |  0.011523 |  0.108275 |
# |  530965-INDIAN OIL CORPORATION LTD   |      FValue 100      |  0.502793  |  0.105828 | 0.000709 | 0.016298 |  0.011543 |  0.107323 |
# |        532174-ICICI BANK LTD         |   Coefficients 0.1   |  0.486637  | -0.183757 | 0.000829 | 0.018829 |  0.012888 | -0.183639 |
# |        532174-ICICI BANK LTD         |     PValue 0.02      |  0.511136  | -0.165901 | 0.000816 | 0.018724 |  0.012684 | -0.165901 |
# |        532174-ICICI BANK LTD         |     PValue 0.05      |  0.475501  | -0.167352 | 0.000817 | 0.018762 |  0.01259  | -0.166853 |
# |        532174-ICICI BANK LTD         |      PValue 0.1      |  0.475501  | -0.167352 | 0.000817 | 0.018762 |  0.01259  | -0.166853 |
# |        532174-ICICI BANK LTD         |      PValue 0.2      |  0.492205  | -0.529032 | 0.00107  | 0.019645 |  0.012829 | -0.528643 |
# |        532174-ICICI BANK LTD         |  ForwardSelection    |  0.491091  | -0.177636 | 0.000824 | 0.018822 |  0.012816 |  -0.17739 |
# |        532174-ICICI BANK LTD         | BackwardElimination  |  0.491091  | -3.031091 | 0.002821 | 0.02032  |  0.012882 | -3.029172 |
# |        532174-ICICI BANK LTD         |       FValue 1       |  0.493318  | -0.823742 | 0.001276 | 0.019561 |  0.012926 | -0.823649 |
# |        532174-ICICI BANK LTD         |      FValue 10       |  0.481069  | -0.183604 | 0.000828 | 0.01884  |  0.012856 | -0.183603 |
# |        532174-ICICI BANK LTD         |      FValue 100      |  0.492205  | -0.182246 | 0.000827 | 0.018843 |  0.012868 | -0.182079 |
# |        532174-ICICI BANK LTD         |     FValue 1000      |  0.528953  | -0.174593 | 0.000822 | 0.018749 |  0.012767 | -0.174593 |
# |      532210-CITY UNION BANK LTD      |     PValue 0.05      |  0.479263  | -0.000281 | 0.000439 | 0.014397 |  0.009972 |  -5.4e-05 |
# |      532210-CITY UNION BANK LTD      |      PValue 0.1      |  0.481567  |  0.001516 | 0.000438 | 0.014389 |  0.009979 |  0.001723 |
# |      532210-CITY UNION BANK LTD      |      PValue 0.2      |  0.476959  |  0.003222 | 0.000437 | 0.014395 |  0.009863 |  0.003222 |
# |      532210-CITY UNION BANK LTD      |  ForwardSelection    |  0.474654  |  0.001983 | 0.000438 | 0.014393 |  0.00996  |  0.002069 |
# |      532210-CITY UNION BANK LTD      | BackwardElimination  |  0.474654  |  0.001983 | 0.000438 | 0.014393 |  0.00996  |  0.002069 |
# |      532210-CITY UNION BANK LTD      |       FValue 1       |  0.488479  |  0.000681 | 0.000438 | 0.014396 |  0.010081 |  0.001027 |
# | 532540-TATA CONSULTANCY SERVICES LTD |   Coefficients 0.1   |  0.53125   |  0.025199 | 0.000593 | 0.012935 |  0.008979 |  0.028865 |
# | 532540-TATA CONSULTANCY SERVICES LTD |     PValue 0.02      |  0.528846  | -5.157781 | 0.003745 | 0.015639 |  0.008892 | -5.127554 |
# | 532540-TATA CONSULTANCY SERVICES LTD |     PValue 0.05      |  0.542067  | -7.871705 | 0.005396 | 0.016177 |  0.009129 |  -7.83691 |
# | 532540-TATA CONSULTANCY SERVICES LTD |      PValue 0.1      |  0.53726   | -4.055996 | 0.003075 | 0.015585 |  0.009161 |  -4.03141 |
# | 532540-TATA CONSULTANCY SERVICES LTD |      PValue 0.2      |  0.53726   | -4.055996 | 0.003075 | 0.015585 |  0.009161 |  -4.03141 |
# | 532540-TATA CONSULTANCY SERVICES LTD |  ForwardSelection    |  0.524038  | -5.034432 | 0.00367  | 0.015593 |  0.00891  | -5.005154 |
# | 532540-TATA CONSULTANCY SERVICES LTD | BackwardElimination  |  0.528846  | -5.157781 | 0.003745 | 0.015639 |  0.008892 | -5.127554 |
# | 532540-TATA CONSULTANCY SERVICES LTD |       FValue 1       |  0.528846  | -3.268333 | 0.002596 | 0.015078 |  0.008972 | -3.246846 |
# | 532540-TATA CONSULTANCY SERVICES LTD |      FValue 10       |  0.544471  |  0.014186 |  0.0006  | 0.012942 |  0.00896  |  0.017683 |
# | 532540-TATA CONSULTANCY SERVICES LTD |      FValue 100      |  0.544471  |  0.014186 |  0.0006  | 0.012942 |  0.00896  |  0.017683 |
# +--------------------------------------+----------------------+------------+-----------+----------+----------+-----------+-----------+

# %%
final_df
# Out:
#                                  Company                   Model  \
# 0                            500112-SBIN       Linear Regression
# 1                            500112-SBIN        Ridge Regression
# 2                            500112-SBIN        Lasso Regression
# 3                            500112-SBIN  Elastic Net Regression
# 4                   500180-HDFC Bank Ltd       Linear Regression
# 5                   500180-HDFC Bank Ltd        Ridge Regression
# 6                   500180-HDFC Bank Ltd        Lasso Regression
# 7                   500180-HDFC Bank Ltd  Elastic Net Regression
# 8               500182-HERO MOTOCORP LTD       Linear Regression
# 9               500182-HERO MOTOCORP LTD        Ridge Regression
# 10              500182-HERO MOTOCORP LTD        Lasso Regression
# 11              500182-HERO MOTOCORP LTD  Elastic Net Regression
# 12                    500209-INFOSYS LTD       Linear Regression
# 13                    500209-INFOSYS LTD        Ridge Regression
# 14                    500209-INFOSYS LTD        Lasso Regression
# 15                    500209-INFOSYS LTD  Elastic Net Regression
# 16        500325-RELIANCE INDUSTRIES LTD       Linear Regression
# 17        500325-RELIANCE INDUSTRIES LTD        Ridge Regression
# 18        500325-RELIANCE INDUSTRIES LTD        Lasso Regression
# 19        500325-RELIANCE INDUSTRIES LTD  Elastic Net Regression
# 20                     500680-PFIZER LTD       Linear Regression
# 21                     500680-PFIZER LTD        Ridge Regression
# 22                     500680-PFIZER LTD        Lasso Regression
# 23                     500680-PFIZER LTD  Elastic Net Regression
# 24                      507685-WIPRO LTD       Linear Regression
# 25                      507685-WIPRO LTD        Ridge Regression
# 26                      507685-WIPRO LTD        Lasso Regression
# 27                      507685-WIPRO LTD  Elastic Net Regression
# 28     530965-INDIAN OIL CORPORATION LTD       Linear Regression
# 29     530965-INDIAN OIL CORPORATION LTD        Ridge Regression
# 30     530965-INDIAN OIL CORPORATION LTD        Lasso Regression
# 31     530965-INDIAN OIL CORPORATION LTD  Elastic Net Regression
# 32                 532174-ICICI BANK LTD       Linear Regression
# 33                 532174-ICICI BANK LTD        Ridge Regression
# 34                 532174-ICICI BANK LTD        Lasso Regression
# 35                 532174-ICICI BANK LTD  Elastic Net Regression
# 36            532210-CITY UNION BANK LTD       Linear Regression
# 37            532210-CITY UNION BANK LTD        Ridge Regression
# 38            532210-CITY UNION BANK LTD        Lasso Regression
# 39            532210-CITY UNION BANK LTD  Elastic Net Regression
# 40  532540-TATA CONSULTANCY SERVICES LTD       Linear Regression
# 41  532540-TATA CONSULTANCY SERVICES LTD        Ridge Regression
# 42  532540-TATA CONSULTANCY SERVICES LTD        Lasso Regression
# 43  532540-TATA CONSULTANCY SERVICES LTD  Elastic Net Regression
# 44                           500112-SBIN                     SVR
# 45                  500180-HDFC Bank Ltd                     SVR
# 46              500182-HERO MOTOCORP LTD                     SVR
# 47                    500209-INFOSYS LTD                     SVR
# 48        500325-RELIANCE INDUSTRIES LTD                     SVR
# 49                     500680-PFIZER LTD                     SVR
# 50                      507685-WIPRO LTD                     SVR
# 51     530965-INDIAN OIL CORPORATION LTD                     SVR
# 52                 532174-ICICI BANK LTD                     SVR
# 53            532210-CITY UNION BANK LTD                     SVR
# 54  532540-TATA CONSULTANCY SERVICES LTD                     SVR
#
#                           Method  Percentage
# 0             LinearFIPValue0.05    0.528953
# 1                RidgeFIFValue10    0.504454
# 2               LassoFIFValue100    0.511136
# 3             ElasticFIFValue100    0.503341
# 4                LinearFIFValue1    0.488294
# 5                 RidgeFIFValue1    0.486065
# 6                 LassoFIFValue1    0.488294
# 7               ElasticFIFValue1    0.488294
# 8    LinearFIBackwardElimination    0.537778
# 9     RidgeFIBackwardElimination    0.537778
# 10    LassoFIBackwardElimination    0.537778
# 11  ElasticFIBackwardElimination    0.537778
# 12       LinearFICoefficients0.1    0.506118
# 13       RidgeFIForwardSelection    0.494994
# 14                LassoFIFValue1    0.490545
# 15      ElasticFICoefficients0.1    0.511680
# 16            LinearFIPValue0.05    0.502781
# 17    RidgeFIBackwardElimination    0.500556
# 18              LassoFIFValue100    0.479422
# 19            ElasticFIFValue100    0.479422
# 20      LinearFIForwardSelection    0.539773
# 21       RidgeFIForwardSelection    0.538636
# 22       LassoFIForwardSelection    0.539773
# 23     ElasticFIForwardSelection    0.539773
# 24       LinearFICoefficients0.1    0.516741
# 25              RidgeFIFValue100    0.511161
# 26              LassoFIPValue0.2    0.517857
# 27            ElasticFIFValue100    0.513393
# 28             LinearFIFValue100    0.516201
# 29               RidgeFIFValue10    0.525140
# 30              LassoFIPValue0.2    0.517318
# 31            ElasticFIPValue0.2    0.517318
# 32   LinearFIBackwardElimination    0.501114
# 33    RidgeFIBackwardElimination    0.510022
# 34             LassoFIFValue1000    0.514477
# 35           ElasticFIFValue1000    0.507795
# 36   LinearFIBackwardElimination    0.489631
# 37                RidgeFIFValue1    0.508065
# 38                LassoFIFValue1    0.482719
# 39              ElasticFIFValue1    0.482719
# 40             LinearFIPValue0.2    0.493990
# 41             RidgeFIPValue0.05    0.480769
# 42              LassoFIFValue100    0.491587
# 43            ElasticFIFValue100    0.489183
# 44             SVR_FI_FValue_100    0.504454
# 45            SVR_FI_FValue_1000    0.540691
# 46       SVR_FI_Coefficients_0.1    0.520000
# 47       SVR_FI_Coefficients_0.1    0.516129
# 48             SVR_FI_PValue_0.2    0.491657
# 49               SVR_FI_FValue_1    0.513636
# 50             SVR_FI_PValue_0.2    0.525670
# 51   SVR_FI_BackwardElimination_    0.518436
# 52            SVR_FI_FValue_1000    0.528953
# 53               SVR_FI_FValue_1    0.488479
# 54             SVR_FI_FValue_100    0.544471
