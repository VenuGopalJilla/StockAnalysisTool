# %%
import pandas as pd

# %%
df1 = pd.read_csv("C:\\Users\\venu\\Desktop\\Stock Market Analysis\\Data\\Models_Results\\df_Final_Results.csv")
df1
# Out:
#                                         Company              Model  \
# 0    500085-CHAMBAL FERTILISERS & CHEMICALS LTD     KNN-Regression
# 1    500085-CHAMBAL FERTILISERS & CHEMICALS LTD     RNN-Regression
# 2    500085-CHAMBAL FERTILISERS & CHEMICALS LTD   Ridge Regression
# 3    500085-CHAMBAL FERTILISERS & CHEMICALS LTD  Linear Regression
# 4    500085-CHAMBAL FERTILISERS & CHEMICALS LTD   Lasso Regression
# ..                                          ...                ...
# 219            542602-EMBASSY OFFICE PARKS REIT  Linear Regression
# 220            542602-EMBASSY OFFICE PARKS REIT   Ridge Regression
# 221            542602-EMBASSY OFFICE PARKS REIT     KNN-Regression
# 222            542602-EMBASSY OFFICE PARKS REIT     RNN-Regression
# 223            542602-EMBASSY OFFICE PARKS REIT                SVR
#
#                                           Method  Percentage
# 0         KNN_Regression_FI_BackwardElimination_    0.540342
# 1     RNN_Regression_FI_AllFeaturesConsideration    0.513447
# 2                                 RidgeFIFValue1    0.506112
# 3                    LinearFIBackwardElimination    0.501222
# 4                                LassoFIFValue10    0.497555
# ..                                           ...         ...
# 219                      LinearFICoefficients0.1    0.538462
# 220                       RidgeFICoefficients0.1    0.538462
# 221  KNN_Regression_FI_AllFeaturesConsideration_    0.530769
# 222        RNN_Regression_FI_BackwardElimination    0.507692
# 223                              SVR_FI_FValue_1    0.484615
#
# [224 rows x 4 columns]

# %%
df2 = pd.read_csv("C:\\Users\\venu\\Desktop\\Stock Market Analysis\\Data\\Models_Results\\df_Final_Results_GRNN_Kaggle.csv")
df2
# Out:
#                                         Company                   Model  \
# 0    500085-CHAMBAL FERTILISERS & CHEMICALS LTD                    GRNN
# 1    500085-CHAMBAL FERTILISERS & CHEMICALS LTD        Ridge Regression
# 2    500085-CHAMBAL FERTILISERS & CHEMICALS LTD       Linear Regression
# 3    500085-CHAMBAL FERTILISERS & CHEMICALS LTD        Lasso Regression
# 4    500085-CHAMBAL FERTILISERS & CHEMICALS LTD  Elastic Net Regression
# ..                                          ...                     ...
# 155            542602-EMBASSY OFFICE PARKS REIT                    GRNN
# 156            542602-EMBASSY OFFICE PARKS REIT        Lasso Regression
# 157            542602-EMBASSY OFFICE PARKS REIT  Elastic Net Regression
# 158            542602-EMBASSY OFFICE PARKS REIT       Linear Regression
# 159            542602-EMBASSY OFFICE PARKS REIT        Ridge Regression
#
#                                          Method  Percentage
# 0    GRNN_FI_AllFeaturesConsideration_stds_0.01    0.985330
# 1                                RidgeFIFValue1    0.506112
# 2                   LinearFIBackwardElimination    0.501222
# 3                               LassoFIFValue10    0.497555
# 4                             ElasticFIFValue10    0.497555
# ..                                          ...         ...
# 155  GRNN_FI_AllFeaturesConsideration_stds_0.01    0.961538
# 156                            LassoFIPValue0.1    0.569231
# 157                          ElasticFIPValue0.1    0.569231
# 158                     LinearFICoefficients0.1    0.538462
# 159                      RidgeFICoefficients0.1    0.538462
#
# [160 rows x 4 columns]

# %%
new_df = pd.concat([df1, df2]).drop_duplicates()
new_df
# Out:
#                                         Company              Model  \
# 0    500085-CHAMBAL FERTILISERS & CHEMICALS LTD     KNN-Regression
# 1    500085-CHAMBAL FERTILISERS & CHEMICALS LTD     RNN-Regression
# 2    500085-CHAMBAL FERTILISERS & CHEMICALS LTD   Ridge Regression
# 3    500085-CHAMBAL FERTILISERS & CHEMICALS LTD  Linear Regression
# 4    500085-CHAMBAL FERTILISERS & CHEMICALS LTD   Lasso Regression
# ..                                          ...                ...
# 135                     533260-CAREER POINT LTD               GRNN
# 140                        533287-ZEE LEARN LTD               GRNN
# 145           537291-NATH BIO-GENES (INDIA) LTD               GRNN
# 150   539921-SHANTI EDUCATIONAL INITIATIVES LTD               GRNN
# 155            542602-EMBASSY OFFICE PARKS REIT               GRNN
#
#                                          Method  Percentage
# 0        KNN_Regression_FI_BackwardElimination_    0.540342
# 1    RNN_Regression_FI_AllFeaturesConsideration    0.513447
# 2                                RidgeFIFValue1    0.506112
# 3                   LinearFIBackwardElimination    0.501222
# 4                               LassoFIFValue10    0.497555
# ..                                          ...         ...
# 135  GRNN_FI_AllFeaturesConsideration_stds_0.01    0.984448
# 140  GRNN_FI_AllFeaturesConsideration_stds_0.01    0.996805
# 145  GRNN_FI_AllFeaturesConsideration_stds_0.01    0.995283
# 150       GRNN_FI_BackwardElimination_stds_0.01    0.709402
# 155  GRNN_FI_AllFeaturesConsideration_stds_0.01    0.961538
#
# [256 rows x 4 columns]

# %%
new_df = new_df.sort_values(by = ['Company', 'Percentage'], ascending = [True, False])
new_df.to_csv('C:\\Users\\venu\\Desktop\\Stock Market Analysis\\Data\\Models_Results\\df_Final_Results_afterGRNN.csv')

# %%
new_df
# Out:
#                                         Company              Model  \
# 0    500085-CHAMBAL FERTILISERS & CHEMICALS LTD               GRNN
# 0    500085-CHAMBAL FERTILISERS & CHEMICALS LTD     KNN-Regression
# 1    500085-CHAMBAL FERTILISERS & CHEMICALS LTD     RNN-Regression
# 2    500085-CHAMBAL FERTILISERS & CHEMICALS LTD   Ridge Regression
# 3    500085-CHAMBAL FERTILISERS & CHEMICALS LTD  Linear Regression
# ..                                          ...                ...
# 219            542602-EMBASSY OFFICE PARKS REIT  Linear Regression
# 220            542602-EMBASSY OFFICE PARKS REIT   Ridge Regression
# 221            542602-EMBASSY OFFICE PARKS REIT     KNN-Regression
# 222            542602-EMBASSY OFFICE PARKS REIT     RNN-Regression
# 223            542602-EMBASSY OFFICE PARKS REIT                SVR
#
#                                           Method  Percentage
# 0     GRNN_FI_AllFeaturesConsideration_stds_0.01    0.985330
# 0         KNN_Regression_FI_BackwardElimination_    0.540342
# 1     RNN_Regression_FI_AllFeaturesConsideration    0.513447
# 2                                 RidgeFIFValue1    0.506112
# 3                    LinearFIBackwardElimination    0.501222
# ..                                           ...         ...
# 219                      LinearFICoefficients0.1    0.538462
# 220                       RidgeFICoefficients0.1    0.538462
# 221  KNN_Regression_FI_AllFeaturesConsideration_    0.530769
# 222        RNN_Regression_FI_BackwardElimination    0.507692
# 223                              SVR_FI_FValue_1    0.484615
#
# [256 rows x 4 columns]
