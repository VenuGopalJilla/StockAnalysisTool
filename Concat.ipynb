# %%
import pandas as pd

# %%
df1 = pd.read_csv("C:\\Users\\venu\\Desktop\\Stock Market Analysis\\Data\\Models_Results\\Final_Results_dataframe.csv")
df1
# Out:
#                                         Company                   Model  \
# 0    500085-CHAMBAL FERTILISERS & CHEMICALS LTD          KNN-Regression
# 1    500085-CHAMBAL FERTILISERS & CHEMICALS LTD        Ridge Regression
# 2    500085-CHAMBAL FERTILISERS & CHEMICALS LTD       Linear Regression
# 3    500085-CHAMBAL FERTILISERS & CHEMICALS LTD        Lasso Regression
# 4    500085-CHAMBAL FERTILISERS & CHEMICALS LTD  Elastic Net Regression
# ..                                          ...                     ...
# 155            542602-EMBASSY OFFICE PARKS REIT        Lasso Regression
# 156            542602-EMBASSY OFFICE PARKS REIT  Elastic Net Regression
# 157            542602-EMBASSY OFFICE PARKS REIT       Linear Regression
# 158            542602-EMBASSY OFFICE PARKS REIT        Ridge Regression
# 159            542602-EMBASSY OFFICE PARKS REIT          KNN-Regression
#
#                                           Method  Percentage
# ...

# %%
df2 = pd.read_csv("C:\\Users\\venu\\Desktop\\Stock Market Analysis\\Data\\Models_Results\\Final_Results_dataframe_afterGRNN.csv")
df2
# Out:
#                                         Company                   Model  \
# 0    500085-CHAMBAL FERTILISERS & CHEMICALS LTD          KNN-Regression
# 1    500085-CHAMBAL FERTILISERS & CHEMICALS LTD        Ridge Regression
# 2    500085-CHAMBAL FERTILISERS & CHEMICALS LTD       Linear Regression
# 3    500085-CHAMBAL FERTILISERS & CHEMICALS LTD                    GRNN
# 4    500085-CHAMBAL FERTILISERS & CHEMICALS LTD        Lasso Regression
# ..                                          ...                     ...
# 187            542602-EMBASSY OFFICE PARKS REIT  Elastic Net Regression
# 188            542602-EMBASSY OFFICE PARKS REIT       Linear Regression
# 189            542602-EMBASSY OFFICE PARKS REIT        Ridge Regression
# 190            542602-EMBASSY OFFICE PARKS REIT          KNN-Regression
# 191            542602-EMBASSY OFFICE PARKS REIT                    GRNN
#
#                                           Method  Percentage
# ...

# %%
new_df = pd.concat([df1, df2]).drop_duplicates()
new_df
# Out:
#                                         Company                   Model  \
# 0    500085-CHAMBAL FERTILISERS & CHEMICALS LTD          KNN-Regression
# 1    500085-CHAMBAL FERTILISERS & CHEMICALS LTD        Ridge Regression
# 2    500085-CHAMBAL FERTILISERS & CHEMICALS LTD       Linear Regression
# 3    500085-CHAMBAL FERTILISERS & CHEMICALS LTD        Lasso Regression
# 4    500085-CHAMBAL FERTILISERS & CHEMICALS LTD  Elastic Net Regression
# ..                                          ...                     ...
# 164                     533260-CAREER POINT LTD                    GRNN
# 169                        533287-ZEE LEARN LTD                    GRNN
# 179           537291-NATH BIO-GENES (INDIA) LTD                    GRNN
# 183   539921-SHANTI EDUCATIONAL INITIATIVES LTD                    GRNN
# 191            542602-EMBASSY OFFICE PARKS REIT                    GRNN
#
#                                      Method  Percentage
# ...

# %%
# new_df = new_df.sort_values(by = ['Company', 'Percentage'], ascending = [True, False])
# new_df.to_csv('C:\\Users\\venu\\Desktop\\Stock Market Analysis\\Data\\Models_Results\\df_Final_Results_afterGRNN.csv')

# %%
# new_df

# %%
df3 = pd.read_csv("C:\\Users\\venu\\Desktop\\Stock Market Analysis\\Data\\Models_Results\\Final_Results_dataframe_afterRNN.csv")
df3
# Out:
#                                         Company                   Model  \
# 0    500085-CHAMBAL FERTILISERS & CHEMICALS LTD          KNN-Regression
# 1    500085-CHAMBAL FERTILISERS & CHEMICALS LTD        Ridge Regression
# 2    500085-CHAMBAL FERTILISERS & CHEMICALS LTD       Linear Regression
# 3    500085-CHAMBAL FERTILISERS & CHEMICALS LTD          RNN-Regression
# 4    500085-CHAMBAL FERTILISERS & CHEMICALS LTD        Lasso Regression
# ..                                          ...                     ...
# 187            542602-EMBASSY OFFICE PARKS REIT  Elastic Net Regression
# 188            542602-EMBASSY OFFICE PARKS REIT          RNN-Regression
# 189            542602-EMBASSY OFFICE PARKS REIT       Linear Regression
# 190            542602-EMBASSY OFFICE PARKS REIT        Ridge Regression
# 191            542602-EMBASSY OFFICE PARKS REIT          KNN-Regression
#
#                                           Method  Percentage
# ...

# %%
new_df1 = pd.concat([new_df, df3]).drop_duplicates()
new_df1
# Out:
#                                         Company                   Model  \
# 0    500085-CHAMBAL FERTILISERS & CHEMICALS LTD          KNN-Regression
# 1    500085-CHAMBAL FERTILISERS & CHEMICALS LTD        Ridge Regression
# 2    500085-CHAMBAL FERTILISERS & CHEMICALS LTD       Linear Regression
# 3    500085-CHAMBAL FERTILISERS & CHEMICALS LTD        Lasso Regression
# 4    500085-CHAMBAL FERTILISERS & CHEMICALS LTD  Elastic Net Regression
# ..                                          ...                     ...
# 167                     533260-CAREER POINT LTD          RNN-Regression
# 169                        533287-ZEE LEARN LTD          RNN-Regression
# 178           537291-NATH BIO-GENES (INDIA) LTD          RNN-Regression
# 185   539921-SHANTI EDUCATIONAL INITIATIVES LTD          RNN-Regression
# 188            542602-EMBASSY OFFICE PARKS REIT          RNN-Regression
#
#                                      Method  Percentage
# ...

# %%
df4 = pd.read_csv("C:\\Users\\venu\\Desktop\\Stock Market Analysis\\Data\\Models_Results\\Final_Results_dataframe_afterSVR.csv")
df4
# Out:
#                                         Company                   Model  \
# 0    500085-CHAMBAL FERTILISERS & CHEMICALS LTD          KNN-Regression
# 1    500085-CHAMBAL FERTILISERS & CHEMICALS LTD        Ridge Regression
# 2    500085-CHAMBAL FERTILISERS & CHEMICALS LTD       Linear Regression
# 3    500085-CHAMBAL FERTILISERS & CHEMICALS LTD        Lasso Regression
# 4    500085-CHAMBAL FERTILISERS & CHEMICALS LTD  Elastic Net Regression
# ..                                          ...                     ...
# 187            542602-EMBASSY OFFICE PARKS REIT  Elastic Net Regression
# 188            542602-EMBASSY OFFICE PARKS REIT       Linear Regression
# 189            542602-EMBASSY OFFICE PARKS REIT        Ridge Regression
# 190            542602-EMBASSY OFFICE PARKS REIT          KNN-Regression
# 191            542602-EMBASSY OFFICE PARKS REIT                     SVR
#
#                                           Method  Percentage
# ...

# %%
new_df2 = pd.concat([new_df1, df4]).drop_duplicates()
new_df2
# Out:
#                                         Company                   Model  \
# 0    500085-CHAMBAL FERTILISERS & CHEMICALS LTD          KNN-Regression
# 1    500085-CHAMBAL FERTILISERS & CHEMICALS LTD        Ridge Regression
# 2    500085-CHAMBAL FERTILISERS & CHEMICALS LTD       Linear Regression
# 3    500085-CHAMBAL FERTILISERS & CHEMICALS LTD        Lasso Regression
# 4    500085-CHAMBAL FERTILISERS & CHEMICALS LTD  Elastic Net Regression
# ..                                          ...                     ...
# 162                     533260-CAREER POINT LTD                     SVR
# 168                        533287-ZEE LEARN LTD                     SVR
# 174           537291-NATH BIO-GENES (INDIA) LTD                     SVR
# 184   539921-SHANTI EDUCATIONAL INITIATIVES LTD                     SVR
# 191            542602-EMBASSY OFFICE PARKS REIT                     SVR
#
#                                      Method  Percentage
# ...

# %%
new_df3 = new_df2.sort_values(by = ['Company', 'Percentage'], ascending = [True, False])
new_df3.to_csv('C:\\Users\\venu\\Desktop\\Stock Market Analysis\\Data\\Models_Results\\Final_Results_dataframe_afterKaggle.csv')
new_df3
# Out:
#                                         Company                   Model  \
# 0    500085-CHAMBAL FERTILISERS & CHEMICALS LTD          KNN-Regression
# 1    500085-CHAMBAL FERTILISERS & CHEMICALS LTD        Ridge Regression
# 2    500085-CHAMBAL FERTILISERS & CHEMICALS LTD       Linear Regression
# 3    500085-CHAMBAL FERTILISERS & CHEMICALS LTD        Lasso Regression
# 4    500085-CHAMBAL FERTILISERS & CHEMICALS LTD  Elastic Net Regression
# ..                                          ...                     ...
# 157            542602-EMBASSY OFFICE PARKS REIT       Linear Regression
# 158            542602-EMBASSY OFFICE PARKS REIT        Ridge Regression
# 159            542602-EMBASSY OFFICE PARKS REIT          KNN-Regression
# 191            542602-EMBASSY OFFICE PARKS REIT                     SVR
# 191            542602-EMBASSY OFFICE PARKS REIT                    GRNN
#
#                                           Method  Percentage
# ...
