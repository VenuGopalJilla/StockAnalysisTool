# %%
import os
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
import time
import calendar
import datetime
import requests
from bs4 import BeautifulSoup
import traceback

# %%
path = os.path.join(os.getcwd(),"Data")
revenuepath = os.path.join(path,"Revenue1")

# %%
def download_revenue_profit(code,name): 

    path = os.path.join(os.getcwd(),"Data\\Revenue1")

    def create_driver():
        chromeOptions = webdriver.ChromeOptions()
        chromeOptions.add_argument("--headless")
        chromeOptions.add_experimental_option("prefs",{"download.default_directory":path})
        driver = webdriver.Chrome(ChromeDriverManager().install(), options = chromeOptions)
        return driver

    def download():
        columns = ["security code","security name",'revenue','income','expenditure','profit','eps',"year","quartile"]
        code_df = pd.DataFrame(columns=columns)
        c = 0
        for q in range(55,110):
            try:
                url = "https://www.bseindia.com/corporates/results.aspx?Code=" + str(code) +"&Company="+ str(name) +"&qtr="+ str(q) +"&RType=D"
                driver.get(url)
                html = driver.page_source
                soup = BeautifulSoup(html, "html")

                table = soup.find_all("table",attrs={"id":"ContentPlaceHolder1_tbl_typeID"})
                table = pd.read_html(str(table))[0]
                table = table[[0,1]]
                table.dropna(inplace=True)
                table = table.transpose()
                table.columns = table.iloc[0]
                table = table[1:]
                table.columns = map(str.lower, table.columns)
                table.drop(["description"],inplace=True,axis=1)
                try:
                    table["date begin"] = pd.to_datetime(table["date begin"])
                    date = table.iloc[0]["date begin"]
                    table["quartile"] =  (date.month-1)//3 + 1
                    table["year"] = date.year
                    table["security name"] = name
                    table["security code"] = code
                    cols = table.columns
                    mycols = ['revenue','income','expenditure','profit','eps']
                    row = {}
                    row["security name"] = name
                    row["security code"] = code
                    row["year"] = date.year
                    row["quartile"] = (date.month-1)//3 + 1
                    for my in mycols:
                        res = [c for c in cols if my in c]
                        if my == "income":
                            p = [c for c in res if "total income" == c ] 
                            res = p or res
                        elif my == "profit":
                            p = [c for c in res if "net profit" == c]
                            res = p or res
                        elif my == "expenditure":
                            p = [c for c in cols if "expenses" in c]
                            res = p or res
                        elif my =="eps":
                            a = "Basic for discontinued & continuing operation"
                            b = "Diluted for discontinued & continuing operation"
                            p = [c for c in cols if a.lower() in c or b.lower() in c]
                            res = p or res
                        elif my == "revenue":
                            p = [c for c in cols if "sales" in c]
                            res = p or res
                            pass
                        row[my] = table[res].values[0][0]
                    code_df = code_df.append(row,ignore_index=True)
                except Exception as e:
                    traceback.print_exc()
            except Exception as e:
                traceback.print_exc()
                c += 1
        if (c < 55):
            code_df.to_csv(os.path.join(path,str(code)+".csv"),index=None)
    driver = create_driver()
    download()
    driver.quit()

# %%
df_equity = pd.read_csv("C:\\Users\\venu\\Desktop\\Stock Market Analysis\\Data\\Equity.csv")
security_numbers = df_equity["Security Code"].tolist()
security_names = df_equity["Security Name"].tolist()
sec = list(zip(security_numbers, security_names))

# %%
# sec[216]
# Out:
# (500440, 'HINDALCO INDUSTRIES LTD.')

# %%
# %%time

for sec_num, sec_name in sec[216 : 300]:
    print(sec_num, sec_name)
    download_revenue_profit(sec_num, sec_name)
#     break
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 90.0.4430
# [WDM] - Get LATEST driver version for 90.0.4430
# 500402 SPML Infra Limited
# [WDM] - Driver [C:\Users\venu\.wdm\drivers\chromedriver\win32\90.0.4430.24\chromedriver.exe] found in cache
# Traceback (most recent call last):
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py", line 3080, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4554, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4562, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'date begin'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 33, in download
#     table["date begin"] = pd.to_datetime(table["date begin"])
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\frame.py", line 3024, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py", line 3082, in get_loc
#     raise KeyError(key) from err
# KeyError: 'date begin'
# Traceback (most recent call last):
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py", line 3080, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4554, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4562, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'date begin'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 33, in download
#     table["date begin"] = pd.to_datetime(table["date begin"])
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\frame.py", line 3024, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py", line 3082, in get_loc
#     raise KeyError(key) from err
# KeyError: 'date begin'
# Traceback (most recent call last):
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py", line 3080, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4554, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4562, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'date begin'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 33, in download
#     table["date begin"] = pd.to_datetime(table["date begin"])
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\frame.py", line 3024, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py", line 3082, in get_loc
#     raise KeyError(key) from err
# KeyError: 'date begin'
# Traceback (most recent call last):
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py", line 3080, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4554, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4562, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'date begin'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 33, in download
#     table["date begin"] = pd.to_datetime(table["date begin"])
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\frame.py", line 3024, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py", line 3082, in get_loc
#     raise KeyError(key) from err
# KeyError: 'date begin'
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 90.0.4430
# [WDM] - Get LATEST driver version for 90.0.4430
# 500403 SUNDRAM FASTENERS LTD.
# [WDM] - Driver [C:\Users\venu\.wdm\drivers\chromedriver\win32\90.0.4430.24\chromedriver.exe] found in cache
# Traceback (most recent call last):
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py", line 3080, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4554, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4562, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'date begin'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 33, in download
#     table["date begin"] = pd.to_datetime(table["date begin"])
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\frame.py", line 3024, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py", line 3082, in get_loc
#     raise KeyError(key) from err
# KeyError: 'date begin'
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 90.0.4430
# [WDM] - Get LATEST driver version for 90.0.4430
# 500404 SUNFLAG IRON & STEEL CO.LTD.
# [WDM] - Driver [C:\Users\venu\.wdm\drivers\chromedriver\win32\90.0.4430.24\chromedriver.exe] found in cache
# Traceback (most recent call last):
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py", line 3080, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4554, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4562, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'date begin'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 33, in download
#     table["date begin"] = pd.to_datetime(table["date begin"])
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\frame.py", line 3024, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py", line 3082, in get_loc
#     raise KeyError(key) from err
# KeyError: 'date begin'
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 90.0.4430
# [WDM] - Get LATEST driver version for 90.0.4430
# 500405 SUPREME PETROCHEM LTD.
# [WDM] - Driver [C:\Users\venu\.wdm\drivers\chromedriver\win32\90.0.4430.24\chromedriver.exe] found in cache
# Traceback (most recent call last):
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py", line 3080, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4554, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4562, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'date begin'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 33, in download
#     table["date begin"] = pd.to_datetime(table["date begin"])
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\frame.py", line 3024, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py", line 3082, in get_loc
#     raise KeyError(key) from err
# KeyError: 'date begin'
# Traceback (most recent call last):
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py", line 3080, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4554, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4562, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'date begin'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 33, in download
#     table["date begin"] = pd.to_datetime(table["date begin"])
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\frame.py", line 3024, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py", line 3082, in get_loc
#     raise KeyError(key) from err
# KeyError: 'date begin'
# Traceback (most recent call last):
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py", line 3080, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4554, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4562, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'date begin'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 33, in download
#     table["date begin"] = pd.to_datetime(table["date begin"])
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\frame.py", line 3024, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py", line 3082, in get_loc
#     raise KeyError(key) from err
# KeyError: 'date begin'
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 90.0.4430
# [WDM] - Get LATEST driver version for 90.0.4430
# 500407 SWARAJ ENGINES LTD.
# [WDM] - Driver [C:\Users\venu\.wdm\drivers\chromedriver\win32\90.0.4430.24\chromedriver.exe] found in cache
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 90.0.4430
# [WDM] - Get LATEST driver version for 90.0.4430
# 500408 TATA ELXSI LTD.
# [WDM] - Driver [C:\Users\venu\.wdm\drivers\chromedriver\win32\90.0.4430.24\chromedriver.exe] found in cache
# Traceback (most recent call last):
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py", line 3080, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4554, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4562, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'date begin'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 33, in download
#     table["date begin"] = pd.to_datetime(table["date begin"])
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\frame.py", line 3024, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py", line 3082, in get_loc
#     raise KeyError(key) from err
# KeyError: 'date begin'
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 90.0.4430
# [WDM] - Get LATEST driver version for 90.0.4430
# 500410 ACC LTD.
# [WDM] - Driver [C:\Users\venu\.wdm\drivers\chromedriver\win32\90.0.4430.24\chromedriver.exe] found in cache
# Traceback (most recent call last):
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py", line 3080, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4554, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4562, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'date begin'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 33, in download
#     table["date begin"] = pd.to_datetime(table["date begin"])
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\frame.py", line 3024, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py", line 3082, in get_loc
#     raise KeyError(key) from err
# KeyError: 'date begin'
# Traceback (most recent call last):
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py", line 3080, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4554, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4562, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'date begin'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 33, in download
#     table["date begin"] = pd.to_datetime(table["date begin"])
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\frame.py", line 3024, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py", line 3082, in get_loc
#     raise KeyError(key) from err
# KeyError: 'date begin'
# Traceback (most recent call last):
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py", line 3080, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4554, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4562, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'date begin'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 33, in download
#     table["date begin"] = pd.to_datetime(table["date begin"])
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\frame.py", line 3024, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py", line 3082, in get_loc
#     raise KeyError(key) from err
# KeyError: 'date begin'
# Traceback (most recent call last):
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py", line 3080, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4554, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4562, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'date begin'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 33, in download
#     table["date begin"] = pd.to_datetime(table["date begin"])
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\frame.py", line 3024, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py", line 3082, in get_loc
#     raise KeyError(key) from err
# KeyError: 'date begin'
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 90.0.4430
# [WDM] - Get LATEST driver version for 90.0.4430
# 500411 THERMAX LTD.
# [WDM] - Driver [C:\Users\venu\.wdm\drivers\chromedriver\win32\90.0.4430.24\chromedriver.exe] found in cache
# Traceback (most recent call last):
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py", line 3080, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4554, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4562, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'date begin'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 33, in download
#     table["date begin"] = pd.to_datetime(table["date begin"])
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\frame.py", line 3024, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py", line 3082, in get_loc
#     raise KeyError(key) from err
# KeyError: 'date begin'
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 90.0.4430
# [WDM] - Get LATEST driver version for 90.0.4430
# 500412 THIRUMALAI CHEMICALS LTD.
# [WDM] - Driver [C:\Users\venu\.wdm\drivers\chromedriver\win32\90.0.4430.24\chromedriver.exe] found in cache
# Traceback (most recent call last):
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py", line 3080, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4554, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4562, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'date begin'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 33, in download
#     table["date begin"] = pd.to_datetime(table["date begin"])
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\frame.py", line 3024, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py", line 3082, in get_loc
#     raise KeyError(key) from err
# KeyError: 'date begin'
# Traceback (most recent call last):
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py", line 3080, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4554, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4562, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'date begin'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 33, in download
#     table["date begin"] = pd.to_datetime(table["date begin"])
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\frame.py", line 3024, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py", line 3082, in get_loc
#     raise KeyError(key) from err
# KeyError: 'date begin'
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 90.0.4430
# [WDM] - Get LATEST driver version for 90.0.4430
# 500413 THOMAS COOK (INDIA) LTD.
# [WDM] - Driver [C:\Users\venu\.wdm\drivers\chromedriver\win32\90.0.4430.24\chromedriver.exe] found in cache
# Traceback (most recent call last):
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py", line 3080, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4554, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4562, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'date begin'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 33, in download
#     table["date begin"] = pd.to_datetime(table["date begin"])
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\frame.py", line 3024, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py", line 3082, in get_loc
#     raise KeyError(key) from err
# KeyError: 'date begin'
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 90.0.4430
# [WDM] - Get LATEST driver version for 90.0.4430
# 500414 TIMEX GROUP INDIA LTD.-$
# [WDM] - Driver [C:\Users\venu\.wdm\drivers\chromedriver\win32\90.0.4430.24\chromedriver.exe] found in cache
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 66, in download
#     row[my] = table[res].values[0][0]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 66, in download
#     row[my] = table[res].values[0][0]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 66, in download
#     row[my] = table[res].values[0][0]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Traceback (most recent call last):
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py", line 3080, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4554, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4562, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'date begin'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 33, in download
#     table["date begin"] = pd.to_datetime(table["date begin"])
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\frame.py", line 3024, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py", line 3082, in get_loc
#     raise KeyError(key) from err
# KeyError: 'date begin'
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 90.0.4430
# [WDM] - Get LATEST driver version for 90.0.4430
# 500418 TOKYO PLAST INTERNATIONAL LTD.
# [WDM] - Driver [C:\Users\venu\.wdm\drivers\chromedriver\win32\90.0.4430.24\chromedriver.exe] found in cache
# Traceback (most recent call last):
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py", line 3080, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4554, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4562, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'date begin'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 33, in download
#     table["date begin"] = pd.to_datetime(table["date begin"])
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\frame.py", line 3024, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py", line 3082, in get_loc
#     raise KeyError(key) from err
# KeyError: 'date begin'
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 90.0.4430
# [WDM] - Get LATEST driver version for 90.0.4430
# 500420 TORRENT PHARMACEUTICALS LTD.
# [WDM] - Driver [C:\Users\venu\.wdm\drivers\chromedriver\win32\90.0.4430.24\chromedriver.exe] found in cache
# Traceback (most recent call last):
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py", line 3080, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4554, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4562, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'date begin'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 33, in download
#     table["date begin"] = pd.to_datetime(table["date begin"])
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\frame.py", line 3024, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py", line 3082, in get_loc
#     raise KeyError(key) from err
# KeyError: 'date begin'
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 90.0.4430
# [WDM] - Get LATEST driver version for 90.0.4430
# 500422 TRANSCHEM LTD.-$
# [WDM] - Driver [C:\Users\venu\.wdm\drivers\chromedriver\win32\90.0.4430.24\chromedriver.exe] found in cache
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 66, in download
#     row[my] = table[res].values[0][0]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 66, in download
#     row[my] = table[res].values[0][0]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 66, in download
#     row[my] = table[res].values[0][0]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 66, in download
#     row[my] = table[res].values[0][0]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 66, in download
#     row[my] = table[res].values[0][0]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 66, in download
#     row[my] = table[res].values[0][0]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 66, in download
#     row[my] = table[res].values[0][0]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 66, in download
#     row[my] = table[res].values[0][0]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 66, in download
#     row[my] = table[res].values[0][0]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 66, in download
#     row[my] = table[res].values[0][0]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 66, in download
#     row[my] = table[res].values[0][0]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 66, in download
#     row[my] = table[res].values[0][0]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 66, in download
#     row[my] = table[res].values[0][0]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 66, in download
#     row[my] = table[res].values[0][0]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 66, in download
#     row[my] = table[res].values[0][0]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 66, in download
#     row[my] = table[res].values[0][0]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 66, in download
#     row[my] = table[res].values[0][0]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 66, in download
#     row[my] = table[res].values[0][0]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 66, in download
#     row[my] = table[res].values[0][0]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 66, in download
#     row[my] = table[res].values[0][0]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 66, in download
#     row[my] = table[res].values[0][0]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 66, in download
#     row[my] = table[res].values[0][0]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 66, in download
#     row[my] = table[res].values[0][0]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 66, in download
#     row[my] = table[res].values[0][0]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 66, in download
#     row[my] = table[res].values[0][0]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 66, in download
#     row[my] = table[res].values[0][0]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 66, in download
#     row[my] = table[res].values[0][0]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 66, in download
#     row[my] = table[res].values[0][0]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 66, in download
#     row[my] = table[res].values[0][0]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 66, in download
#     row[my] = table[res].values[0][0]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 66, in download
#     row[my] = table[res].values[0][0]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 66, in download
#     row[my] = table[res].values[0][0]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 66, in download
#     row[my] = table[res].values[0][0]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 66, in download
#     row[my] = table[res].values[0][0]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 66, in download
#     row[my] = table[res].values[0][0]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 66, in download
#     row[my] = table[res].values[0][0]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 66, in download
#     row[my] = table[res].values[0][0]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 66, in download
#     row[my] = table[res].values[0][0]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 66, in download
#     row[my] = table[res].values[0][0]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 66, in download
#     row[my] = table[res].values[0][0]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 66, in download
#     row[my] = table[res].values[0][0]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 66, in download
#     row[my] = table[res].values[0][0]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 66, in download
#     row[my] = table[res].values[0][0]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 66, in download
#     row[my] = table[res].values[0][0]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 66, in download
#     row[my] = table[res].values[0][0]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 66, in download
#     row[my] = table[res].values[0][0]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 66, in download
#     row[my] = table[res].values[0][0]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 66, in download
#     row[my] = table[res].values[0][0]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 66, in download
#     row[my] = table[res].values[0][0]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 66, in download
#     row[my] = table[res].values[0][0]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 66, in download
#     row[my] = table[res].values[0][0]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 66, in download
#     row[my] = table[res].values[0][0]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 66, in download
#     row[my] = table[res].values[0][0]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Traceback (most recent call last):
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py", line 3080, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4554, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4562, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'date begin'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 33, in download
#     table["date begin"] = pd.to_datetime(table["date begin"])
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\frame.py", line 3024, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py", line 3082, in get_loc
#     raise KeyError(key) from err
# KeyError: 'date begin'
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 90.0.4430
# [WDM] - Get LATEST driver version for 90.0.4430
# 500425 AMBUJA CEMENTS LTD.
# [WDM] - Driver [C:\Users\venu\.wdm\drivers\chromedriver\win32\90.0.4430.24\chromedriver.exe] found in cache
# Traceback (most recent call last):
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py", line 3080, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4554, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4562, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'date begin'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 33, in download
#     table["date begin"] = pd.to_datetime(table["date begin"])
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\frame.py", line 3024, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py", line 3082, in get_loc
#     raise KeyError(key) from err
# KeyError: 'date begin'
# Traceback (most recent call last):
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py", line 3080, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4554, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4562, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'date begin'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 33, in download
#     table["date begin"] = pd.to_datetime(table["date begin"])
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\frame.py", line 3024, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py", line 3082, in get_loc
#     raise KeyError(key) from err
# KeyError: 'date begin'
# Traceback (most recent call last):
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py", line 3080, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4554, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4562, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'date begin'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 33, in download
#     table["date begin"] = pd.to_datetime(table["date begin"])
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\frame.py", line 3024, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py", line 3082, in get_loc
#     raise KeyError(key) from err
# KeyError: 'date begin'
# Traceback (most recent call last):
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py", line 3080, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4554, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4562, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'date begin'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 33, in download
#     table["date begin"] = pd.to_datetime(table["date begin"])
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\frame.py", line 3024, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py", line 3082, in get_loc
#     raise KeyError(key) from err
# KeyError: 'date begin'
# Traceback (most recent call last):
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py", line 3080, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4554, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4562, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'date begin'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 33, in download
#     table["date begin"] = pd.to_datetime(table["date begin"])
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\frame.py", line 3024, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py", line 3082, in get_loc
#     raise KeyError(key) from err
# KeyError: 'date begin'
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 90.0.4430
# [WDM] - Get LATEST driver version for 90.0.4430
# 500426 UTL Industries Limited
# [WDM] - Driver [C:\Users\venu\.wdm\drivers\chromedriver\win32\90.0.4430.24\chromedriver.exe] found in cache
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 66, in download
#     row[my] = table[res].values[0][0]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 66, in download
#     row[my] = table[res].values[0][0]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 66, in download
#     row[my] = table[res].values[0][0]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 66, in download
#     row[my] = table[res].values[0][0]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 66, in download
#     row[my] = table[res].values[0][0]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 66, in download
#     row[my] = table[res].values[0][0]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 66, in download
#     row[my] = table[res].values[0][0]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 66, in download
#     row[my] = table[res].values[0][0]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# ...
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4554, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4562, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'date begin'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 33, in download
#     table["date begin"] = pd.to_datetime(table["date begin"])
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\frame.py", line 3024, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py", line 3082, in get_loc
#     raise KeyError(key) from err
# KeyError: 'date begin'
# Traceback (most recent call last):
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py", line 3080, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4554, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4562, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'date begin'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 33, in download
#     table["date begin"] = pd.to_datetime(table["date begin"])
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\frame.py", line 3024, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py", line 3082, in get_loc
#     raise KeyError(key) from err
# KeyError: 'date begin'
# Traceback (most recent call last):
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py", line 3080, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4554, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4562, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'date begin'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 33, in download
#     table["date begin"] = pd.to_datetime(table["date begin"])
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\frame.py", line 3024, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py", line 3082, in get_loc
#     raise KeyError(key) from err
# KeyError: 'date begin'
# Traceback (most recent call last):
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py", line 3080, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4554, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4562, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'date begin'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 33, in download
#     table["date begin"] = pd.to_datetime(table["date begin"])
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\frame.py", line 3024, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py", line 3082, in get_loc
#     raise KeyError(key) from err
# KeyError: 'date begin'
# Traceback (most recent call last):
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py", line 3080, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4554, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4562, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'date begin'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 33, in download
#     table["date begin"] = pd.to_datetime(table["date begin"])
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\frame.py", line 3024, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py", line 3082, in get_loc
#     raise KeyError(key) from err
# KeyError: 'date begin'
# Traceback (most recent call last):
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py", line 3080, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4554, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4562, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'date begin'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 33, in download
#     table["date begin"] = pd.to_datetime(table["date begin"])
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\frame.py", line 3024, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py", line 3082, in get_loc
#     raise KeyError(key) from err
# KeyError: 'date begin'
# Traceback (most recent call last):
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py", line 3080, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4554, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4562, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'date begin'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "<ipython-input-3-58925499f0a0>", line 33, in download
#     table["date begin"] = pd.to_datetime(table["date begin"])
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\frame.py", line 3024, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\Users\venu\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py", line 3082, in get_loc
#     raise KeyError(key) from err
# KeyError: 'date begin'
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 90.0.4430
# [WDM] - Get LATEST driver version for 90.0.4430
# 500440 HINDALCO INDUSTRIES LTD.
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\anaconda3\envs\tf\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     168         try:
# --> 169             conn = connection.create_connection(
#     170                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~\anaconda3\envs\tf\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      72
# ---> 73     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      74         af, socktype, proto, canonname, sa = res
#
# ~\anaconda3\envs\tf\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     917     addrlist = []
# --> 918     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     919         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~\anaconda3\envs\tf\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# ~\anaconda3\envs\tf\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#
# ~\anaconda3\envs\tf\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#    1009         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1010             conn.connect()
#    1011
#
# ~\anaconda3\envs\tf\lib\site-packages\urllib3\connection.py in connect(self)
#     352         # Add certificate verification
# --> 353         conn = self._new_conn()
#     354         hostname = self.host
#
# ~\anaconda3\envs\tf\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     180         except SocketError as e:
# --> 181             raise NewConnectionError(
#     182                 self, "Failed to establish a new connection: %s" % e
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x000001EC23FEE340>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~\anaconda3\envs\tf\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# ~\anaconda3\envs\tf\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     754
# --> 755             retries = retries.increment(
#     756                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# ~\anaconda3\envs\tf\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     572         if new_retry.is_exhausted():
# --> 573             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     574
#
# MaxRetryError: HTTPSConnectionPool(host='chromedriver.storage.googleapis.com', port=443): Max retries exceeded with url: /LATEST_RELEASE_90.0.4430 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001EC23FEE340>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <timed exec> in <module>
#
# <ipython-input-3-58925499f0a0> in download_revenue_profit(code, name)
#      73         if (c < 55):
#      74             code_df.to_csv(os.path.join(path,str(code)+".csv"),index=None)
# ---> 75     driver = create_driver()
#      76     download()
#      77     driver.quit()
#
# <ipython-input-3-58925499f0a0> in create_driver()
#       7         chromeOptions.add_argument("--headless")
#       8         chromeOptions.add_experimental_option("prefs",{"download.default_directory":path})
# ----> 9         driver = webdriver.Chrome(ChromeDriverManager().install(), options = chromeOptions)
#      10         return driver
#      11
#
# ~\anaconda3\envs\tf\lib\site-packages\webdriver_manager\chrome.py in install(self)
#      32     def install(self):
#      33         log(f"Current {self.driver.chrome_type} version is {self.driver.browser_version}", first_line=True)
# ---> 34         driver_path = self._get_driver_path(self.driver)
#      35
#      36         os.chmod(driver_path, 0o755)
#
# ~\anaconda3\envs\tf\lib\site-packages\webdriver_manager\manager.py in _get_driver_path(self, driver)
#      19         driver_name = driver.get_name()
#      20         os_type = driver.get_os_type()
# ---> 21         driver_version = driver.get_version()
#      22
#      23         binary_path = self.driver_cache.find_driver(browser_version, driver_name, os_type,
#
# ~\anaconda3\envs\tf\lib\site-packages\webdriver_manager\driver.py in get_version(self)
#      38         driver_version = self._version
#      39         if driver_version == "latest":
# ---> 40             return self.get_latest_release_version()
#      41         return self._version
#      42
#
# ~\anaconda3\envs\tf\lib\site-packages\webdriver_manager\driver.py in get_latest_release_version(self)
#      61     def get_latest_release_version(self):
#      62         log(f"Get LATEST driver version for {self.browser_version}")
# ---> 63         resp = requests.get(f"{self._latest_release_url}_{self.browser_version}")
#      64         validate_response(resp)
#      65         return resp.text.rstrip()
#
# ~\anaconda3\envs\tf\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~\anaconda3\envs\tf\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\anaconda3\envs\tf\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~\anaconda3\envs\tf\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~\anaconda3\envs\tf\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='chromedriver.storage.googleapis.com', port=443): Max retries exceeded with url: /LATEST_RELEASE_90.0.4430 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001EC23FEE340>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
